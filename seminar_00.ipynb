# %%
import urllib
import requests

# %%
from urllib.parse import urlparse
from urllib.parse import urldefrag
import time

# %%
from urllib.request import urlopen

def download_from_the_internet(url):
    try:
        return urlopen(url).read().decode('utf-8')
    except KeyboardInterrupt:
        raise
    except urllib.error.HTTPError as e:
        code = e.code
        if code != 404:
            print(e)
        return code
    except Exception as e:
        print(e)

# %%
urlparse('https://simple.wikipedia.org/wiki/Main_Page')
# Out:
# ParseResult(scheme='https', netloc='simple.wikipedia.org', path='/wiki/Main_Page', params='', query='', fragment='')

# %% [markdown]
# В file_storage.py определил операторы in и len для удобства:
#
# ```python
# def __contains__(self, key):
#     return key in self._dict
#
# def __len__(self):
#     return len(self._dict)
# ```

# %%
from file_storage import FileStorage

file_storage = FileStorage('storage')

# %%
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def extract_links_from_html(url, html):
    parser = BeautifulSoup(html)
    return [urljoin(url, link.get('href')) for link in parser.findAll('a')]

# %%
import pickle
state_file_path = 'state.pickle'

def dump_state(iteration, urls_to_visit):
    with open(state_file_path, 'wb') as state_file:
        pickle.dump((iteration, urls_to_visit), state_file)
        print('state saved, iteration {}'.format(iteration))

def load_state():
    with open(state_file_path, 'rb') as state_file:
        return pickle.load(state_file)

# %%
urls_to_visit = {'https://simple.wikipedia.org/wiki/Main_Page'}
iteration = 0

# %%
beginning = 'https://simple.wikipedia.org/wiki/'
ban_patterns = [
    'Help', 'Wikipedia', 'Special', 'File', 'Template', 'Talk',
    'Template_talk', 'User_talk', 'User', 'Meta', 'user', 'MediaWiki',
    'Wikipedia_talk', 'Category_talk', 'Module', 'Media'
]
ban_patterns = [pattern + ':' for pattern in ban_patterns]
ban_patterns.append('Requests_for_comment')

def filter_url(url):
    if not url.startswith(beginning):
        return True
    url_end = url[len(beginning):]
    return any(url_end.startswith(ban_pattern) for ban_pattern in ban_patterns)

# %%
from multiprocessing.pool import Pool

# %%
import os
cpu_count = os.cpu_count()

# %% [markdown]
# В начале я почему-то думал, что там 1,4кк страниц, а не 140к. Поэтому немного заморочился и сделал скачивание и парсинг в несколько потоков. На утро понял, что затупил и можно было проще)

# %%
def parse_url(url):
    for attempt in range(2):
        html = download_from_the_internet(url)
        time.sleep(0.2)
        if (isinstance(html, int) and html == 404):
            return None
        elif html is not None:
            break
    else:
        return None

    urls = extract_links_from_html(url, html)
    return url, html, urls


def manage_parsing_result(parsing_result, file_storage, iteration, urls_to_visit):
    new_url, new_html, new_urls = parsing_result
    if new_url in file_storage:
        return iteration
    
    file_storage.write(new_url, new_html)
    defraged_urls = (urldefrag(url).url for url in new_urls)
    fresh_urls = [
        url for url in defraged_urls
        if url not in file_storage and not filter_url(url)
    ]
    urls_to_visit.update(fresh_urls)
    iteration += 1
    dump_state(iteration, urls_to_visit)
    return iteration


def download_wiki(file_storage, iteration, urls_to_visit):
    results = []
    with Pool() as pool:
        while urls_to_visit or results:
            new_url = urls_to_visit.pop()
            if new_url in file_storage:
                continue
            results.append(pool.apply_async(parse_url, (new_url,)))
            for ind, result in enumerate(results):
                if result.ready():
                    completed_result = result.get()
                    results.pop(ind)
                    break
            else:
                if len(results) < cpu_count - 1 and urls_to_visit:
                    continue
                else:
                    parsing_result = None
                    while parsing_result is None and results:
                        parsing_result = results[0].get()
                        results.pop(0)
                    if parsing_result is None:
                        continue
            iteration = manage_parsing_result(parsing_result, file_storage, iteration, urls_to_visit)

# %%
iteration, urls_to_visit = load_state()
download_wiki(file_storage, iteration, urls_to_visit)

# %%
len(file_storage)
# Out:
# 193170

# %%
len(file_storage) - len([key for key in file_storage.keys() if key[len(beginning):].startswith('Category:')])
# Out:
# 151127

# %%
download_from_the_internet('https://simple.wikipedia.org/wiki/R50/53:_Very_toxic_to_aquatic_organisms,_may_cause_long-term_adverse_effects_in_the aquatic_environment')
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of R-phrases - Simple English Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_R-phrases","wgTitle":"List of R-phrases","wgCurRevisionId":4482389,"wgRevisionId":4482389,"wgArticleId":269558,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Safety","Chemistry lists"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"List_of_R-phrases","wgRelevantArticleId":269558,"wgRequestId":"XGefpwpAICwAAIKO18UAAABW","wgCSPNonce":false,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgRedirectedFrom":"R50/53:_Very_toxic_to_aquatic_organisms,_may_cause_long-term_adverse_effects_in_the_aquatic_environment","wgCategoryTreePageCategoryOptions":"{\\"mode\\":0,\\"hideprefix\\":20,\\"showcount\\":true,\\"namespaces\\":false}","wgWikiEditorEnabledModules":[],"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":true,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en","usePageImages":true,"usePageDescriptions":true},"wgMFIsPageContentModelEditable":true,"wgMFEnableFontChanger":true,"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgWMESchemaEditAttemptStepOversample":false,"wgPoweredByHHVM":true,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgInternalRedirectTargetUrl":"/wiki/List_of_R-phrases","wgWikibaseItemId":"Q309012","wgScoreNoteLanguages":{"arabic":"العربية","catalan":"català","deutsch":"Deutsch","english":"English","espanol":"español","italiano":"italiano","nederlands":"Nederlands","norsk":"norsk","portugues":"português","suomi":"suomi","svenska":"svenska","vlaams":"West-Vlams"},"wgScoreDefaultNoteLanguage":"nederlands","wgCentralAuthMobileDomain":false,"wgCodeMirrorEnabled":true,"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":true,"oresWikiId":"simplewiki","oresBaseUrl":"http://ores.discovery.wmnet:8081/","oresApiVersion":3});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"});mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n}); ...

# %%
def redirect_url(page):
    if 'wgRedirectedFrom"' in page:
        page_name_pattern = 'wgPageName":"'
        begin_ind = page.index(page_name_pattern)
        begin_ind += len(page_name_pattern)
        end_ind = page.index('"', begin_ind)
        return beginning + page[begin_ind:end_ind]

# %%
def is_article(page):
    pattern = '"wgIsArticle":'
    begin_ind = page.index(pattern)
    begin_ind += len(pattern)
    end_ind = page.index(',', begin_ind)
    answer = page[begin_ind:end_ind]
    if answer == "true":
        return True
    elif answer == 'false':
        return False
    else:
        return answer

# %%
is_article(download_from_the_internet('https://simple.wikipedia.org/wiki/Special:CategoryTree'))
# Out:
# False

# %%
is_article(file_storage.read('https://simple.wikipedia.org/wiki/Category:Establishments_in_France'))
# Out:
# True

# %%
is_article(file_storage.read('https://simple.wikipedia.org/wiki/Cat'))
# Out:
# True

# %% [markdown]
# Wow, wiki считает категории статьями?

# %%
for url, page in file_storage.items():
    a = is_article(page)
    if isinstance(a, str):
        print(a, url)
        break
    elif not a:
        print(url)

# %% [markdown]
# Жаль, тут ничего лишнего не нашли(

# %% [markdown]
# Уберем редиректы

# %%
file_storage_without_redirects = FileStorage('without_redirects')

# %%
for url, page in file_storage.items():
    redirect = redirect_url(page)
    if redirect is not None:
        if redirect not in file_storage:
            print(redirect)
            file_storage_without_redirects.write(redirect, page)
    else:
        file_storage_without_redirects.write(url, page)
# Out:
# https://simple.wikipedia.org/wiki/Polish–Soviet_War
# https://simple.wikipedia.org/wiki/Centralism
# https://simple.wikipedia.org/wiki/Niccolò_Machiavelli
# https://simple.wikipedia.org/wiki/Sinéad_O'Connor
# https://simple.wikipedia.org/wiki/Chloë_Moretz
# https://simple.wikipedia.org/wiki/Pago_Pago,_American_Samoa
# https://simple.wikipedia.org/wiki/Njord
# https://simple.wikipedia.org/wiki/Bandage
# https://simple.wikipedia.org/wiki/Gdańsk
# https://simple.wikipedia.org/wiki/Saikaidō_Seamounts
# https://simple.wikipedia.org/wiki/Motörhead
# https://simple.wikipedia.org/wiki/Árpád_Göncz
# https://simple.wikipedia.org/wiki/Diego_Velázquez
# https://simple.wikipedia.org/wiki/Bahá'í_Faith
# https://simple.wikipedia.org/wiki/Görlitz
# https://simple.wikipedia.org/wiki/Wilhelm_Röntgen
# https://simple.wikipedia.org/wiki/12_Super_Éxitos
# https://simple.wikipedia.org/wiki/Jehovah's_Witnesses
# https://simple.wikipedia.org/wiki/National_Chiao_Tung_University
# https://simple.wikipedia.org/wiki/Encyclopædia_Britannica
# https://simple.wikipedia.org/wiki/Teachta_Dála
# https://simple.wikipedia.org/wiki/UTC+04:00
# https://simple.wikipedia.org/wiki/Israeli–Palestinian_conflict
# https://simple.wikipedia.org/wiki/Kenzaburō_Ōe
# https://simple.wikipedia.org/wiki/Christian-Democratic_National_Peasants'_Party_(Romania)
# https://simple.wikipedia.org/wiki/Greco–Persian_wars
# https://simple.wikipedia.org/wiki/Métis_people
# https://simple.wikipedia.org/wiki/Reykjavík
# https://simple.wikipedia.org/wiki/Tōhoku_region
# https://simple.wikipedia.org/wiki/Åland_Islands
# https://simple.wikipedia.org/wiki/Frédéric_Chopin
# https://simple.wikipedia.org/wiki/Pedro_Armendáriz,_Jr.
# https://simple.wikipedia.org/wiki/WWE_TLC:_Tables,_Ladders_\u0026_Chairs
# https://simple.wikipedia.org/wiki/Hachikō
# https://simple.wikipedia.org/wiki/Langues_d'oïl
# https://simple.wikipedia.org/wiki/Coup_d'état
# https://simple.wikipedia.org/wiki/Purchasing_Power_Parity
# https://simple.wikipedia.org/wiki/Hurricane_Joan–Miriam
# https://simple.wikipedia.org/wiki/C.D._Lugo
# https://simple.wikipedia.org/wiki/Battle_of_Ðiện_Biên_Phủ
# https://simple.wikipedia.org/wiki/Nicolás_Maduro
# https://simple.wikipedia.org/wiki/Emperor_Shōwa
# https://simple.wikipedia.org/wiki/Onești
# https://simple.wikipedia.org/wiki/Nicolae_Ceaușescu
# https://simple.wikipedia.org/wiki/Óscar_Arias
# https://simple.wikipedia.org/wiki/Organic_farms
# https://simple.wikipedia.org/wiki/Jóhanna_Sigurðardóttir
# https://simple.wikipedia.org/wiki/Iran–Iraq_War
# https://simple.wikipedia.org/wiki/Chișinău
# https://simple.wikipedia.org/wiki/1983_Invasion_of_Grenada
# https://simple.wikipedia.org/wiki/Louisiana_State_University_and_A\u0026M_College
# https://simple.wikipedia.org/wiki/UTC+05:00
# https://simple.wikipedia.org/wiki/2009–10_NHL_season
# https://simple.wikipedia.org/wiki/Siân_Phillips
# https://simple.wikipedia.org/wiki/Wisława_Szymborska
# https://simple.wikipedia.org/wiki/Simón_Bolívar
# https://simple.wikipedia.org/wiki/C.A._Belgrano
# https://simple.wikipedia.org/wiki/Crosby,_Stills,_Nash_\u0026_Young
# https://simple.wikipedia.org/wiki/Louisiana_State_University_and_A\u0026M_College
# https://simple.wikipedia.org/wiki/List_of_Jupiter's_moons
# https://simple.wikipedia.org/wiki/1939–40_NHL_season
# https://simple.wikipedia.org/wiki/Orléans
# https://simple.wikipedia.org/wiki/Napoléon_III
# https://simple.wikipedia.org/wiki/Severan_dynasty
# https://simple.wikipedia.org/wiki/African-American_Civil_Rights_Movement_(1954–1968)
# https://simple.wikipedia.org/wiki/Rhône
# https://simple.wikipedia.org/wiki/Café
# https://simple.wikipedia.org/wiki/2003–04_NHL_season
# https://simple.wikipedia.org/wiki/Wrocław
# https://simple.wikipedia.org/wiki/Võ_Nguyên_Giáp
# https://simple.wikipedia.org/wiki/Bogotá
# https://simple.wikipedia.org/wiki/Oligochaete
# https://simple.wikipedia.org/wiki/Emperor_Kenzō
# https://simple.wikipedia.org/wiki/Lech_Kaczyński
# https://simple.wikipedia.org/wiki/San_José_State_University
# https://simple.wikipedia.org/wiki/Fermat's_Last_Theorem
# https://simple.wikipedia.org/wiki/Homogeneity
# https://simple.wikipedia.org/wiki/Sinn_Féin
# https://simple.wikipedia.org/wiki/Giant_Gippsland_earthworm
# https://simple.wikipedia.org/wiki/Marie_Thérèse_of_Savoy
# https://simple.wikipedia.org/wiki/Iranian_coup_d'etat_(1953)
# https://simple.wikipedia.org/wiki/1936–37_NHL_season
# https://simple.wikipedia.org/wiki/Jean-François_de_Galaup,_comte_de_Lapérouse
# https://simple.wikipedia.org/wiki/Jōmon_period
# https://simple.wikipedia.org/wiki/Kōō_(Nanboku-chō_period)
# https://simple.wikipedia.org/wiki/Oriole
# https://simple.wikipedia.org/wiki/Urozgan_Province
# https://simple.wikipedia.org/wiki/Emperor_Yōmei
# https://simple.wikipedia.org/wiki/−1_(number)
# https://simple.wikipedia.org/wiki/Sings_the_Ballads_of_the_True_West
# https://simple.wikipedia.org/wiki/Bamyan
# https://simple.wikipedia.org/wiki/Roush_Fenway_Racing
# https://simple.wikipedia.org/wiki/Benito_Juárez
# https://simple.wikipedia.org/wiki/Lawn_mower
# https://simple.wikipedia.org/wiki/François_Arago
# https://simple.wikipedia.org/wiki/Napoléon_III
# https://simple.wikipedia.org/wiki/Marián_Hossa
# https://simple.wikipedia.org/wiki/Saint_Patrick's_Day
# https://simple.wikipedia.org/wiki/Répétiteur
# https://simple.wikipedia.org/wiki/Æsir
# https://simple.wikipedia.org/wiki/Temnospondyl
# https://simple.wikipedia.org/wiki/José_Théodore
# https://simple.wikipedia.org/wiki/Potamogeton
# https://simple.wikipedia.org/wiki/Taíno
# https://simple.wikipedia.org/wiki/Viacom_(1971–2005)
# https://simple.wikipedia.org/wiki/Kraków
# https://simple.wikipedia.org/wiki/Bárbara_of_Portugal
# https://simple.wikipedia.org/wiki/Isabel_Martínez_de_Perón
# https://simple.wikipedia.org/wiki/John_Kasich_2016_presidential_campaign
# https://simple.wikipedia.org/wiki/Esfahān
# https://simple.wikipedia.org/wiki/Réunion
# https://simple.wikipedia.org/wiki/Melk_Abbey
# https://simple.wikipedia.org/wiki/Syndicat_National_de_l'Édition_Phonographique
# https://simple.wikipedia.org/wiki/2001–02_NHL_season
# https://simple.wikipedia.org/wiki/TV_Guide_(magazine)
# https://simple.wikipedia.org/wiki/Ragnarök
# https://simple.wikipedia.org/wiki/Mustafa_Kemal_Atatürk
# https://simple.wikipedia.org/wiki/Kitakyūshū
# https://simple.wikipedia.org/wiki/Cattle_drives_in_the_United_States
# https://simple.wikipedia.org/wiki/Bío_Bío_Region
# https://simple.wikipedia.org/wiki/Napoléon_III
# https://simple.wikipedia.org/wiki/Kōji_Nakata
# https://simple.wikipedia.org/wiki/João_Havelange
# https://simple.wikipedia.org/wiki/Dominik_Hašek
# https://simple.wikipedia.org/wiki/Armed_Forces_of_Belarus
# https://simple.wikipedia.org/wiki/Leadbeater's_possum
# https://simple.wikipedia.org/wiki/Paul_Revere_\u0026_the_Raiders
# https://simple.wikipedia.org/wiki/François_Mitterrand
# https://simple.wikipedia.org/wiki/Nickelodeon_Kids'_Choice_Awards
# https://simple.wikipedia.org/wiki/Déjà_Vu_(song)
# https://simple.wikipedia.org/wiki/Däniken,_Solothurn
# https://simple.wikipedia.org/wiki/Kraków
# https://simple.wikipedia.org/wiki/Linear_Pottery_culture
# https://simple.wikipedia.org/wiki/Vuelta_Ciclista_a_España
# https://simple.wikipedia.org/wiki/1938–39_NHL_season
# https://simple.wikipedia.org/wiki/Objectivism
# https://simple.wikipedia.org/wiki/Georgia
# https://simple.wikipedia.org/wiki/Azərbaycan_marşı
# https://simple.wikipedia.org/wiki/Omar_Khayyám
# https://simple.wikipedia.org/wiki/Carmine_(color)
# https://simple.wikipedia.org/wiki/Stanisław_Wyspiański
# https://simple.wikipedia.org/wiki/St_Stephen's_Cathedral,_Vienna
# https://simple.wikipedia.org/wiki/Opsin
# https://simple.wikipedia.org/wiki/TriStar_(Production_Studio)
# https://simple.wikipedia.org/wiki/Tarinkot
# https://simple.wikipedia.org/wiki/Saffir–Simpson_Hurricane_Scale
# https://simple.wikipedia.org/wiki/Ostallgäu
# https://simple.wikipedia.org/wiki/Ratchet_\u0026_Clank_(movie)
# https://simple.wikipedia.org/wiki/April_2017_Champs-Élysées_attack
# https://simple.wikipedia.org/wiki/Huáscar
# https://simple.wikipedia.org/wiki/1982–83_NHL_season
# https://simple.wikipedia.org/wiki/Río_de_la_Plata
# https://simple.wikipedia.org/wiki/Kingdom_of_Württemberg
# https://simple.wikipedia.org/wiki/Charlotte's_Web_(2006_movie)
# https://simple.wikipedia.org/wiki/Thérèse_of_Lisieux
# https://simple.wikipedia.org/wiki/The_Lord_of_the_Rings_(disambiguation)
# https://simple.wikipedia.org/wiki/Cassini–Huygens
# https://simple.wikipedia.org/wiki/Chuy_García
# https://simple.wikipedia.org/wiki/Folie_à_Deux_(album)
# https://simple.wikipedia.org/wiki/Diet_(nutrition)
# https://simple.wikipedia.org/wiki/1997–98_NHL_season
# https://simple.wikipedia.org/wiki/Musa_ibn_Jafar
# https://simple.wikipedia.org/wiki/People's_Party_for_Freedom_and_Democracy
# https://simple.wikipedia.org/wiki/Marián_Gáborík
# https://simple.wikipedia.org/wiki/Zürich
# https://simple.wikipedia.org/wiki/Élisabeth_of_France_(1764–1794)
# https://simple.wikipedia.org/wiki/History_of_the_United_States_(1789–1849)
# https://simple.wikipedia.org/wiki/Iran–Contra_affair
# https://simple.wikipedia.org/wiki/Mineral_exploration
# https://simple.wikipedia.org/wiki/Barthélemy_Dumortier
# https://simple.wikipedia.org/wiki/Song_Ikp'il
# https://simple.wikipedia.org/wiki/Qur'an
# https://simple.wikipedia.org/wiki/Sarton
# https://simple.wikipedia.org/wiki/Valparaíso
# https://simple.wikipedia.org/wiki/Ole_Gunnar_Solskjær
# https://simple.wikipedia.org/wiki/Ion_Creangă
# https://simple.wikipedia.org/wiki/Adolfo_Suárez
# https://simple.wikipedia.org/wiki/War_in_Afghanistan_(2001–present)
# https://simple.wikipedia.org/wiki/Bifröst
# https://simple.wikipedia.org/wiki/E.C._Vitória
# https://simple.wikipedia.org/wiki/Götterdämmerung
# https://simple.wikipedia.org/wiki/Symphony_No._9_\
# https://simple.wikipedia.org/wiki/BB\u0026T_Center_(Sunrise)
# https://simple.wikipedia.org/wiki/Lewisham_station
# https://simple.wikipedia.org/wiki/Potato_blight
# https://simple.wikipedia.org/wiki/Slobodan_Milošević
# https://simple.wikipedia.org/wiki/Grand_duchy
# https://simple.wikipedia.org/wiki/Yucca_brevifolia
# https://simple.wikipedia.org/wiki/John_C._Frémont
# https://simple.wikipedia.org/wiki/Rhône_(department)
# https://simple.wikipedia.org/wiki/The_Sufferer_\u0026_The_Witness
# https://simple.wikipedia.org/wiki/Oppy
# https://simple.wikipedia.org/wiki/Zambezi_River
# https://simple.wikipedia.org/wiki/Cryptozoology
# https://simple.wikipedia.org/wiki/Saint_Veronica
# https://simple.wikipedia.org/wiki/Forecasting
# https://simple.wikipedia.org/wiki/Ampère's_circuital_law
# https://simple.wikipedia.org/wiki/Diary_of_a_Wimpy_Kid_(series)
# https://simple.wikipedia.org/wiki/People's_Party_(United_States)
# https://simple.wikipedia.org/wiki/Échallens_(district)
# https://simple.wikipedia.org/wiki/Mayor–council_government
# https://simple.wikipedia.org/wiki/Republican_People's_Party
# https://simple.wikipedia.org/wiki/Hōryaku_calendar
# https://simple.wikipedia.org/wiki/Comet_Shoemaker–Levy_9
# https://simple.wikipedia.org/wiki/Charles-Maurice_de_Talleyrand-Périgord
# https://simple.wikipedia.org/wiki/Österreichischer_Fußball-_Bund
# https://simple.wikipedia.org/wiki/Minamisōma
# https://simple.wikipedia.org/wiki/Voice_recorder
# https://simple.wikipedia.org/wiki/Kellogg–Briand_Pact
# https://simple.wikipedia.org/wiki/Börde_Rural_District
# https://simple.wikipedia.org/wiki/Miller–Urey_experiment
# https://simple.wikipedia.org/wiki/Wycliffe's_Bible
# https://simple.wikipedia.org/wiki/Bani_Jamra
# https://simple.wikipedia.org/wiki/People's_Republic_of_China
# https://simple.wikipedia.org/wiki/Angrboða
# https://simple.wikipedia.org/wiki/Organolithium_reagent
# https://simple.wikipedia.org/wiki/Étienne_Geoffroy_Saint-Hilaire
# https://simple.wikipedia.org/wiki/Sensory_receptor
# https://simple.wikipedia.org/wiki/Grand_duchy
# https://simple.wikipedia.org/wiki/Cardenal_Caro
# https://simple.wikipedia.org/wiki/Alliance_'90/The_Greens
# https://simple.wikipedia.org/wiki/List_of_extinct_volcanoes
# https://simple.wikipedia.org/wiki/K–Ar_dating
# https://simple.wikipedia.org/wiki/Die_Walküre
# https://simple.wikipedia.org/wiki/Tassili_n'Ajjer
# https://simple.wikipedia.org/wiki/Lech_Wałęsa
# https://simple.wikipedia.org/wiki/Jens_Böhrnsen
# https://simple.wikipedia.org/wiki/Joaquín_Rodrigo
# https://simple.wikipedia.org/wiki/Marcus_Krüger
# https://simple.wikipedia.org/wiki/Mesut_Özil
# https://simple.wikipedia.org/wiki/Vienna_Symphony
# https://simple.wikipedia.org/wiki/Beauvois
# https://simple.wikipedia.org/wiki/College_of_William_\u0026_Mary
# https://simple.wikipedia.org/wiki/Symphony_No._7_\
# https://simple.wikipedia.org/wiki/Borussia_Mönchengladbach
# https://simple.wikipedia.org/wiki/Republican_People's_Party
# https://simple.wikipedia.org/wiki/War_in_Afghanistan_(2001–present)
# https://simple.wikipedia.org/wiki/Olaf_Kölzig
# https://simple.wikipedia.org/wiki/2010–11_Fußball-Bundesliga
# https://simple.wikipedia.org/wiki/Virginia_opossum
# https://simple.wikipedia.org/wiki/Düsseldorf
# https://simple.wikipedia.org/wiki/Limoges_Cathedral
# https://simple.wikipedia.org/wiki/Sika_Anoaʻi
# https://simple.wikipedia.org/wiki/Pim_Fortuyn_List
# https://simple.wikipedia.org/wiki/Jean_Béliveau
# https://simple.wikipedia.org/wiki/St_Jude_storm
# https://simple.wikipedia.org/wiki/Jarosław_Kaczyński
# https://simple.wikipedia.org/wiki/Centre_(department)
# https://simple.wikipedia.org/wiki/Galápagos_Islands
# https://simple.wikipedia.org/wiki/Lady_Margaret_Beaufort
# https://simple.wikipedia.org/wiki/Galápagos_Islands
# https://simple.wikipedia.org/wiki/Sancti_Spíritus_Province
# https://simple.wikipedia.org/wiki/Hubble's_law
# https://simple.wikipedia.org/wiki/Celâl_Bayar
# https://simple.wikipedia.org/wiki/Beyoncé
# https://simple.wikipedia.org/wiki/Nukuʻalofa
# https://simple.wikipedia.org/wiki/Lilo_\u0026_Stitch
# https://simple.wikipedia.org/wiki/Weddell_seal
# https://simple.wikipedia.org/wiki/Goran_Ivanišević
# https://simple.wikipedia.org/wiki/Westerbork_concentration_camp
# https://simple.wikipedia.org/wiki/Ástor_Piazzolla
# https://simple.wikipedia.org/wiki/Édouard_Manet
# https://simple.wikipedia.org/wiki/Symphony_No.8_\
# https://simple.wikipedia.org/wiki/Christian_Democratic_Appeal
# https://simple.wikipedia.org/wiki/National_emblem_of_Bangladesh
# https://simple.wikipedia.org/wiki/1937–38_NHL_season
# https://simple.wikipedia.org/wiki/Fontvieille
# https://simple.wikipedia.org/wiki/Three_Great_Gardens_of_Japan
# https://simple.wikipedia.org/wiki/Gerard_'t_Hooft
# https://simple.wikipedia.org/wiki/Hotspot
# https://simple.wikipedia.org/wiki/English_Football_League
# https://simple.wikipedia.org/wiki/Arthur_Seyß-Inquart
# https://simple.wikipedia.org/wiki/Wild_Dances
# https://simple.wikipedia.org/wiki/Right-handedness
# https://simple.wikipedia.org/wiki/Gallo_language
# https://simple.wikipedia.org/wiki/Guns_N'_Roses
# https://simple.wikipedia.org/wiki/Elizabeth_Báthory
# https://simple.wikipedia.org/wiki/The_Pilgrim's_Progress
# https://simple.wikipedia.org/wiki/Newton_metre
# https://simple.wikipedia.org/wiki/The_Lion_King_1½
# https://simple.wikipedia.org/wiki/Lomé
# https://simple.wikipedia.org/wiki/Shaving
# https://simple.wikipedia.org/wiki/Icterid
# https://simple.wikipedia.org/wiki/2010–11_Fußball-Bundesliga
# https://simple.wikipedia.org/wiki/Permian–Triassic_extinction_event
# https://simple.wikipedia.org/wiki/Emperor_Go-Sanjō
# https://simple.wikipedia.org/wiki/Béla_Bartók
# https://simple.wikipedia.org/wiki/Władysław_Bartoszewski
# https://simple.wikipedia.org/wiki/Joaquín_Sorolla
# https://simple.wikipedia.org/wiki/War_in_Afghanistan_(2001–present)
# https://simple.wikipedia.org/wiki/1942–43_NHL_season
# https://simple.wikipedia.org/wiki/Tucumán_Province
# https://simple.wikipedia.org/wiki/Leimen,_Baden-Württemberg
# https://simple.wikipedia.org/wiki/Serene_Highness
# https://simple.wikipedia.org/wiki/Raúl_Castro
# https://simple.wikipedia.org/wiki/The_Simpsons:_Hit_\u0026_Run
# https://simple.wikipedia.org/wiki/John_O'Meally
# https://simple.wikipedia.org/wiki/Željko_Šturanović
# https://simple.wikipedia.org/wiki/San_Cristóbal_Ecatepec
# https://simple.wikipedia.org/wiki/Turbot
# https://simple.wikipedia.org/wiki/Chilcotin_Group
# https://simple.wikipedia.org/wiki/Cristina_Fernández_de_Kirchner
# https://simple.wikipedia.org/wiki/Franche-Comté
# https://simple.wikipedia.org/wiki/Pfäffikon,_Zürich
# https://simple.wikipedia.org/wiki/Marcel_Pelletier
# https://simple.wikipedia.org/wiki/Royal_Surrey_Gardens
# https://simple.wikipedia.org/wiki/AT\u0026T
# https://simple.wikipedia.org/wiki/Bunkyū
# https://simple.wikipedia.org/wiki/2000–01_NHL_season
# https://simple.wikipedia.org/wiki/Emperor_Shōwa
# https://simple.wikipedia.org/wiki/I'm_Real_(Jennifer_Lopez_song)
# https://simple.wikipedia.org/wiki/Anne_Marie_Louise_d'Orléans
# https://simple.wikipedia.org/wiki/Wilhelm_Röntgen
# https://simple.wikipedia.org/wiki/1998–99_NHL_season
# https://simple.wikipedia.org/wiki/Oomycete
# https://simple.wikipedia.org/wiki/Magnús_Eiríksson
# https://simple.wikipedia.org/wiki/Emperor_Richū
# https://simple.wikipedia.org/wiki/Ratchet_\u0026_Clank_(series)
# https://simple.wikipedia.org/wiki/Hartsfield–Jackson_Atlanta_International_Airport
# https://simple.wikipedia.org/wiki/Valence,_Drôme
# https://simple.wikipedia.org/wiki/Pak_Chŏng_Hŭi
# https://simple.wikipedia.org/wiki/Planetshine
# https://simple.wikipedia.org/wiki/Portland_Winterhawks
# https://simple.wikipedia.org/wiki/Gnome
# https://simple.wikipedia.org/wiki/The_National_Grange_of_the_Order_of_Patrons_of_Husbandry
# https://simple.wikipedia.org/wiki/Giorgio_Ardisson
# https://simple.wikipedia.org/wiki/Austrian_People's_Party
# https://simple.wikipedia.org/wiki/Ii
# https://simple.wikipedia.org/wiki/Tromsø
# https://simple.wikipedia.org/wiki/Saarbrücken_(district)
# https://simple.wikipedia.org/wiki/Upton_Park
# https://simple.wikipedia.org/wiki/King's_Cross_St._Pancras_tube_station
# https://simple.wikipedia.org/wiki/Bee_hummingbird
# https://simple.wikipedia.org/wiki/Takeshi_Ono
# https://simple.wikipedia.org/wiki/Blue_Öyster_Cult
# https://simple.wikipedia.org/wiki/Pokémon
# https://simple.wikipedia.org/wiki/Jöns_Jacob_Berzelius
# https://simple.wikipedia.org/wiki/Philippe_I,_Duke_of_Orléans
# https://simple.wikipedia.org/wiki/Booker_T._\u0026_the_M.G.'s
# https://simple.wikipedia.org/wiki/Alveolate
# https://simple.wikipedia.org/wiki/Vestigial_organ
# https://simple.wikipedia.org/wiki/It's_Only_Love
# https://simple.wikipedia.org/wiki/Yaya_Touré
# https://simple.wikipedia.org/wiki/Surveyor_General
# https://simple.wikipedia.org/wiki/Chief_of_the_General_Staff
# https://simple.wikipedia.org/wiki/Matsu_Islands
# https://simple.wikipedia.org/wiki/Bird_vocalization
# https://simple.wikipedia.org/wiki/The_Suite_Life_of_Zack_\u0026_Cody
# https://simple.wikipedia.org/wiki/Saikaidō_Seamounts
# https://simple.wikipedia.org/wiki/Léon_Bakst
# https://simple.wikipedia.org/wiki/Vendée
# https://simple.wikipedia.org/wiki/Merovingian_dynasty
# https://simple.wikipedia.org/wiki/Markus_Näslund
# https://simple.wikipedia.org/wiki/Biscarrosse–Parentis_Airport
# https://simple.wikipedia.org/wiki/Folie_à_Deux_(album)
# https://simple.wikipedia.org/wiki/UTC+05:00
# https://simple.wikipedia.org/wiki/Concepción
# https://simple.wikipedia.org/wiki/Pak_Chŏng_Hŭi
# https://simple.wikipedia.org/wiki/Séan_T._O'Kelly
# https://simple.wikipedia.org/wiki/'N_Sync
# https://simple.wikipedia.org/wiki/Shahab_al-Din_Suhrawardi
# https://simple.wikipedia.org/wiki/Jørn_Utzon
# https://simple.wikipedia.org/wiki/Diff'rent_Strokes
# https://simple.wikipedia.org/wiki/Niš
# https://simple.wikipedia.org/wiki/Gdańsk
# https://simple.wikipedia.org/wiki/Hyōgo_Prefecture
# https://simple.wikipedia.org/wiki/Encyclopædia_Britannica
# https://simple.wikipedia.org/wiki/Pima_County,_Arizona
# https://simple.wikipedia.org/wiki/Sébastien_Buemi
# https://simple.wikipedia.org/wiki/List_of_Presidents_of_the_Dominican_Republic
# https://simple.wikipedia.org/wiki/Adolfo_Suárez,_Madrid–Barajas_Airport
# https://simple.wikipedia.org/wiki/Toshirō_Mifune
# https://simple.wikipedia.org/wiki/Calvià
# https://simple.wikipedia.org/wiki/Côte_d'Ivoire_national_football_team
# https://simple.wikipedia.org/wiki/Chicago_\
# https://simple.wikipedia.org/wiki/Ranidae
# https://simple.wikipedia.org/wiki/Günzburg_(district)
# https://simple.wikipedia.org/wiki/Nico_Hülkenberg
# https://simple.wikipedia.org/wiki/John_C._Frémont
# https://simple.wikipedia.org/wiki/Thomson–East_Coast_MRT_line
# https://simple.wikipedia.org/wiki/Lübeck
# https://simple.wikipedia.org/wiki/São_Carlos_F.C.
# https://simple.wikipedia.org/wiki/Lake_Zürich
# https://simple.wikipedia.org/wiki/Queen_Liliʻuokalani
# https://simple.wikipedia.org/wiki/1923_Great_Kantō_earthquake
# https://simple.wikipedia.org/wiki/Leclanche_battery
# https://simple.wikipedia.org/wiki/Florianópolis
# https://simple.wikipedia.org/wiki/Louise_Marie_Adélaïde_de_Bourbon,_Duchess_of_Orléans
# https://simple.wikipedia.org/wiki/Beyoncé
# https://simple.wikipedia.org/wiki/Béla_Fleck
# https://simple.wikipedia.org/wiki/Pangolin
# https://simple.wikipedia.org/wiki/Year_2038_problem
# https://simple.wikipedia.org/wiki/2002–03_NHL_season
# https://simple.wikipedia.org/wiki/Flag_of_the_People's_Republic_of_China
# https://simple.wikipedia.org/wiki/Paul-Henri_Thiry,_Baron_d'Holbach
# https://simple.wikipedia.org/wiki/St._James's_Palace
# https://simple.wikipedia.org/wiki/1996–97_NHL_season
# https://simple.wikipedia.org/wiki/Isurus
# https://simple.wikipedia.org/wiki/Artemisia_absinthium
# https://simple.wikipedia.org/wiki/Castellón_Province
# https://simple.wikipedia.org/wiki/2013–14_Fußball-Bundesliga
# https://simple.wikipedia.org/wiki/Massari_(album)
# https://simple.wikipedia.org/wiki/Müller's_Bornean_gibbon
# https://simple.wikipedia.org/wiki/Study_skills
# https://simple.wikipedia.org/wiki/National_Library_of_Spain
# https://simple.wikipedia.org/wiki/R.C._Deportivo_de_La_Coruña
# https://simple.wikipedia.org/wiki/Höfen,_Thun
# https://simple.wikipedia.org/wiki/Danilo_Medina
# https://simple.wikipedia.org/wiki/Greco–Persian_wars
# https://simple.wikipedia.org/wiki/François_Hollande
# https://simple.wikipedia.org/wiki/William_Nakamura
# https://simple.wikipedia.org/wiki/Gabriel_Fauré
# https://simple.wikipedia.org/wiki/Shaka_Sankofa
# https://simple.wikipedia.org/wiki/Malmö
# https://simple.wikipedia.org/wiki/Rosiers-d'Égletons
# https://simple.wikipedia.org/wiki/Superalloy
# https://simple.wikipedia.org/wiki/Françoise_Barré-Sinoussi
# https://simple.wikipedia.org/wiki/Parkinson's_disease
# https://simple.wikipedia.org/wiki/Stian_Barsnes-Simonsen
# https://simple.wikipedia.org/wiki/The_Curse_of_King_Tut's_Tomb_(1980_movie)
# https://simple.wikipedia.org/wiki/Soldier_(song)
# https://simple.wikipedia.org/wiki/ECW_World_Heavyweight_Championship
# https://simple.wikipedia.org/wiki/Don't_Tell_Me
# https://simple.wikipedia.org/wiki/Sino-Japanese_vocabulary
# https://simple.wikipedia.org/wiki/Michal_Grošek
# https://simple.wikipedia.org/wiki/Teacher's_Pet_(movie)
# https://simple.wikipedia.org/wiki/Tate
# https://simple.wikipedia.org/wiki/Bábism
# https://simple.wikipedia.org/wiki/Prades_(Pyrénées-Orientales)
# https://simple.wikipedia.org/wiki/Luis_Echeverría
# https://simple.wikipedia.org/wiki/Saber–toothed_cat
# https://simple.wikipedia.org/wiki/War_in_Afghanistan_(2001–present)
# https://simple.wikipedia.org/wiki/Kanpō
# https://simple.wikipedia.org/wiki/SWAT_team
# https://simple.wikipedia.org/wiki/Serum_amyloid_A
# https://simple.wikipedia.org/wiki/Greek_Salad
# https://simple.wikipedia.org/wiki/Māori_language
# https://simple.wikipedia.org/wiki/Maltese_lira
# https://simple.wikipedia.org/wiki/Old-growth_forest
# https://simple.wikipedia.org/wiki/Telephone_numbers_in_Australia
# https://simple.wikipedia.org/wiki/Kobe,_Hyōgo
# https://simple.wikipedia.org/wiki/Permian–Triassic_extinction_event
# https://simple.wikipedia.org/wiki/Jeanne_Baptiste_d'Albert_de_Luynes
# https://simple.wikipedia.org/wiki/Saikaidō_Seamounts
# https://simple.wikipedia.org/wiki/Rail
# https://simple.wikipedia.org/wiki/College_of_William_\u0026_Mary
# https://simple.wikipedia.org/wiki/Xu_Xiao-Fei
# https://simple.wikipedia.org/wiki/Iván_Duque_Márquez
# https://simple.wikipedia.org/wiki/São_Tomé_and_Príncipe
# https://simple.wikipedia.org/wiki/Popocatépetl
# https://simple.wikipedia.org/wiki/Beyoncé_discography
# https://simple.wikipedia.org/wiki/Bergstraße_(district)
# https://simple.wikipedia.org/wiki/Francisco_Ibáñez_Talavera
# https://simple.wikipedia.org/wiki/Newton's_laws_of_motion
# https://simple.wikipedia.org/wiki/Álvaro_Torres
# https://simple.wikipedia.org/wiki/Édouard_Manet
# https://simple.wikipedia.org/wiki/Dharmapuri,_Tamil_Nadu
# https://simple.wikipedia.org/wiki/Louise_Élisabeth_d'Orléans
# https://simple.wikipedia.org/wiki/PBR\u0026B
# https://simple.wikipedia.org/wiki/Archduchess_Maria_Clementina_of_Austria
# https://simple.wikipedia.org/wiki/St_Paul's_Girls'_School
# https://simple.wikipedia.org/wiki/Hōtoku
# https://simple.wikipedia.org/wiki/Saskatchewan_River
# https://simple.wikipedia.org/wiki/Xi'an
# https://simple.wikipedia.org/wiki/Humbert
# https://simple.wikipedia.org/wiki/Bowler
# https://simple.wikipedia.org/wiki/The_Brak_Show
# https://simple.wikipedia.org/wiki/Toluca_Municipality
# https://simple.wikipedia.org/wiki/Neuchâtel
# https://simple.wikipedia.org/wiki/Michelson–Morley_experiment
# https://simple.wikipedia.org/wiki/Rely
# https://simple.wikipedia.org/wiki/Jim_Gilmore_2016_presidential_campaign
# https://simple.wikipedia.org/wiki/UTC+01:00
# https://simple.wikipedia.org/wiki/Radiography
# https://simple.wikipedia.org/wiki/Volapük
# https://simple.wikipedia.org/wiki/Sumatran_tiger
# https://simple.wikipedia.org/wiki/Córdoba
# https://simple.wikipedia.org/wiki/King's_Sutton_railway_station
# https://simple.wikipedia.org/wiki/Paul_Cézanne
# https://simple.wikipedia.org/wiki/Young's_double-slit_experiment
# https://simple.wikipedia.org/wiki/Legendary_Pokémon
# https://simple.wikipedia.org/wiki/Aşgabat
# https://simple.wikipedia.org/wiki/Orgy
# https://simple.wikipedia.org/wiki/Johann_Friedrich_Blumenbach
# https://simple.wikipedia.org/wiki/Canon_(official)
# https://simple.wikipedia.org/wiki/Spanish–American_War
# https://simple.wikipedia.org/wiki/Iðunn
# https://simple.wikipedia.org/wiki/Obsessive–compulsive_disorder
# https://simple.wikipedia.org/wiki/Bogotá
# https://simple.wikipedia.org/wiki/Thomas_Müller
# https://simple.wikipedia.org/wiki/St_Stephen's_Cathedral,_Vienna
# https://simple.wikipedia.org/wiki/Martial_Célestin
# https://simple.wikipedia.org/wiki/Idukki_district
# https://simple.wikipedia.org/wiki/Teotihuacán
# https://simple.wikipedia.org/wiki/1999–2000_NHL_season
# https://simple.wikipedia.org/wiki/Chūbu_region
# https://simple.wikipedia.org/wiki/The_Courier-Mail
# https://simple.wikipedia.org/wiki/Ranidae
# https://simple.wikipedia.org/wiki/Cœur_de_pirate
# https://simple.wikipedia.org/wiki/Mika_Häkkinen
# https://simple.wikipedia.org/wiki/O'Hare_International_Airport
# https://simple.wikipedia.org/wiki/Blue_Öyster_Cult
# https://simple.wikipedia.org/wiki/Jaber_al-Ahmad_al-Sabah
# https://simple.wikipedia.org/wiki/I'm_Getting_Used_to_You
# https://simple.wikipedia.org/wiki/E.C._Santo_André
# https://simple.wikipedia.org/wiki/Inca_Empire
# https://simple.wikipedia.org/wiki/Ciudad_Juárez
# https://simple.wikipedia.org/wiki/Arsenous_acid
# https://simple.wikipedia.org/wiki/Jim_Henson's_Muppet_Babies
# https://simple.wikipedia.org/wiki/Pokémon
# https://simple.wikipedia.org/wiki/Mort_\u0026_Phil
# https://simple.wikipedia.org/wiki/A.S._Saint-Étienne
# https://simple.wikipedia.org/wiki/Marie_Thérèse_of_Savoy
# https://simple.wikipedia.org/wiki/Iaşi
# https://simple.wikipedia.org/wiki/Ryōta_Tsuzuki
# https://simple.wikipedia.org/wiki/Puy-de-Dôme
# https://simple.wikipedia.org/wiki/Teplice
# https://simple.wikipedia.org/wiki/S.E._Gama
# https://simple.wikipedia.org/wiki/Bloody_Mary
# https://simple.wikipedia.org/wiki/Jokichi_Ikarashi
# https://simple.wikipedia.org/wiki/Weißeritzkreis_Rural_District
# https://simple.wikipedia.org/wiki/Jalapeño
# https://simple.wikipedia.org/wiki/Prince-Bishopric_of_Liège
# https://simple.wikipedia.org/wiki/Pak_Chŏng_Hŭi
# https://simple.wikipedia.org/wiki/Shinzō_Abe
# https://simple.wikipedia.org/wiki/Kōfu
# https://simple.wikipedia.org/wiki/Toru,_Khyber_Pakhtunkhwa
# https://simple.wikipedia.org/wiki/Pokémon_Gold_and_Silver
# https://simple.wikipedia.org/wiki/Batman_\u0026_Robin
# https://simple.wikipedia.org/wiki/UTC+06:00
# https://simple.wikipedia.org/wiki/Akihiro_Endō
# https://simple.wikipedia.org/wiki/Werra-Meißner-Kreis
# https://simple.wikipedia.org/wiki/Earth's_inner_core
# https://simple.wikipedia.org/wiki/Uluṟu-Kata_Tjuṯa_National_Park
# https://simple.wikipedia.org/wiki/Legendary_Pokémon
# https://simple.wikipedia.org/wiki/Canton_of_Zürich
# https://simple.wikipedia.org/wiki/Law_\u0026_Order:_Special_Victims_Unit
# https://simple.wikipedia.org/wiki/Legendary_Pokémon
# https://simple.wikipedia.org/wiki/Louis,_Duke_of_Orléans_(1703–1752)
# https://simple.wikipedia.org/wiki/Engraving
# https://simple.wikipedia.org/wiki/Emerson,_Lake_\u0026_Palmer
# https://simple.wikipedia.org/wiki/Interception_(football)
# https://simple.wikipedia.org/wiki/List_of_Uranus'_moons
# https://simple.wikipedia.org/wiki/César_Chávez
# https://simple.wikipedia.org/wiki/Franz_Josef_Strauß
# https://simple.wikipedia.org/wiki/Henry_Lee_III
# https://simple.wikipedia.org/wiki/Anglo-Saxon_architecture
# https://simple.wikipedia.org/wiki/2004–05_NHL_season
# https://simple.wikipedia.org/wiki/Unstoppable_(2010_movie)
# https://simple.wikipedia.org/wiki/Robert_Bakker
# https://simple.wikipedia.org/wiki/Types_of_tennis_match
# https://simple.wikipedia.org/wiki/1999–2000_NHL_season
# https://simple.wikipedia.org/wiki/Zdeno_Chára
# https://simple.wikipedia.org/wiki/Ōita_Prefecture
# https://simple.wikipedia.org/wiki/Così_fan_tutte
# https://simple.wikipedia.org/wiki/It_Won't_Be_Soon_Before_Long
# https://simple.wikipedia.org/wiki/Stefán_Karl_Stefánsson
# https://simple.wikipedia.org/wiki/Oriole
# https://simple.wikipedia.org/wiki/José_Raúl_Capablanca
# https://simple.wikipedia.org/wiki/Élisabeth_of_France_(1764–1794)
# https://simple.wikipedia.org/wiki/Leoš_Janáček
# https://simple.wikipedia.org/wiki/Creutzfeldt–Jakob_disease
# https://simple.wikipedia.org/wiki/St._James's_Palace
# https://simple.wikipedia.org/wiki/San_Cristóbal
# https://simple.wikipedia.org/wiki/Bose–Einstein_condensate
# https://simple.wikipedia.org/wiki/Adélie_penguin
# https://simple.wikipedia.org/wiki/Alzheimer's_disease
# https://simple.wikipedia.org/wiki/Le_Havre_AC
# https://simple.wikipedia.org/wiki/Jötnar
# https://simple.wikipedia.org/wiki/Soldier_(song)
# https://simple.wikipedia.org/wiki/École_nationale_supérieure_de_Bordeaux
# https://simple.wikipedia.org/wiki/Texas_hold_'em
# https://simple.wikipedia.org/wiki/Permineralization
# https://simple.wikipedia.org/wiki/Hans-Jörg_Butt
# https://simple.wikipedia.org/wiki/Someone_like_You
# https://simple.wikipedia.org/wiki/Yahadut_HaTorah_HaMeuhedet
# https://simple.wikipedia.org/wiki/Kievan_Rus'
# https://simple.wikipedia.org/wiki/Euler's_identity
# https://simple.wikipedia.org/wiki/Encyclopædia_Britannica
# https://simple.wikipedia.org/wiki/UTC+07:00
# https://simple.wikipedia.org/wiki/One_Flew_Over_the_Cuckoo's_Nest_(movie)
# https://simple.wikipedia.org/wiki/The_Hallé
# https://simple.wikipedia.org/wiki/Pokémon
# https://simple.wikipedia.org/wiki/Münster
# https://simple.wikipedia.org/wiki/Mustafa_Kemal_Atatürk
# https://simple.wikipedia.org/wiki/Stamford
# https://simple.wikipedia.org/wiki/List_of_Pokémon
# https://simple.wikipedia.org/wiki/Izel-lès-Hameau
# https://simple.wikipedia.org/wiki/Éldis_Fernando_Damasio
# https://simple.wikipedia.org/wiki/500s_BC
# https://simple.wikipedia.org/wiki/Hermann_Göring
# https://simple.wikipedia.org/wiki/Saint_Barthélemy
# https://simple.wikipedia.org/wiki/Keizō_Obuchi
# https://simple.wikipedia.org/wiki/Halley's_Comet
# https://simple.wikipedia.org/wiki/Railway_track
# https://simple.wikipedia.org/wiki/Bob_McKenzie
# https://simple.wikipedia.org/wiki/Concepción
# https://simple.wikipedia.org/wiki/Penélope_Cruz
# https://simple.wikipedia.org/wiki/Allen_Dulles
# https://simple.wikipedia.org/wiki/Kōshō
# https://simple.wikipedia.org/wiki/Projection_(mathematics)
# https://simple.wikipedia.org/wiki/Confederación_Sudamericana_de_Fútbol
# https://simple.wikipedia.org/wiki/Master's_degree
# https://simple.wikipedia.org/wiki/Oaxaca_de_Juárez
# https://simple.wikipedia.org/wiki/O'Higgins_Region
# https://simple.wikipedia.org/wiki/Saint_Thomas
# https://simple.wikipedia.org/wiki/Snell's_law
# https://simple.wikipedia.org/wiki/Brusque,_Santa_Catarina
# https://simple.wikipedia.org/wiki/François_Pierre_La_Varenne
# https://simple.wikipedia.org/wiki/Académie_française
# https://simple.wikipedia.org/wiki/Kyūshū
# https://simple.wikipedia.org/wiki/Castle_(disambiguation)
# https://simple.wikipedia.org/wiki/Pokémon
# https://simple.wikipedia.org/wiki/École_normale_supérieure
# https://simple.wikipedia.org/wiki/Microblog
# https://simple.wikipedia.org/wiki/Severan_dynasty
# https://simple.wikipedia.org/wiki/Agnès_Sorel
# https://simple.wikipedia.org/wiki/Inca_Empire
# https://simple.wikipedia.org/wiki/Will_\u0026_Grace
# https://simple.wikipedia.org/wiki/Atlético_Madrid
# https://simple.wikipedia.org/wiki/Yucatán_Peninsula
# https://simple.wikipedia.org/wiki/Win–loss_record_(pitching)
# https://simple.wikipedia.org/wiki/Sulfur_dichloride
# https://simple.wikipedia.org/wiki/São_Paulo_F.C.
# https://simple.wikipedia.org/wiki/Pokémon_Adventures
# https://simple.wikipedia.org/wiki/List_of_Pokémon
# https://simple.wikipedia.org/wiki/Chūbu_International_Airport
# https://simple.wikipedia.org/wiki/João_Ubaldo_Ribeiro
# https://simple.wikipedia.org/wiki/Hyōgo_Prefecture
# https://simple.wikipedia.org/wiki/2011–12_NHL_season
# https://simple.wikipedia.org/wiki/Deoksugung
# https://simple.wikipedia.org/wiki/Ryūe_Nishizawa
# https://simple.wikipedia.org/wiki/New_Zealand_parrot
# https://simple.wikipedia.org/wiki/Brassière
# https://simple.wikipedia.org/wiki/Nîmes
# https://simple.wikipedia.org/wiki/A_Midsummer_Night's_Dream
# https://simple.wikipedia.org/wiki/Gameplay_of_Pokémon
# https://simple.wikipedia.org/wiki/Esox
# https://simple.wikipedia.org/wiki/Regierender_Bürgermeister
# https://simple.wikipedia.org/wiki/Queen's_University
# https://simple.wikipedia.org/wiki/Glaze
# https://simple.wikipedia.org/wiki/Sir_David's_Long-beaked_Echidna
# https://simple.wikipedia.org/wiki/Sněžka
# https://simple.wikipedia.org/wiki/Pokémon
# https://simple.wikipedia.org/wiki/1980–81_NHL_season
# https://simple.wikipedia.org/wiki/Besham
# https://simple.wikipedia.org/wiki/Qur'an
# https://simple.wikipedia.org/wiki/Brain_stem
# https://simple.wikipedia.org/wiki/Magan_(civlization)
# https://simple.wikipedia.org/wiki/Dáil_Éireann
# https://simple.wikipedia.org/wiki/Höchstetten
# https://simple.wikipedia.org/wiki/Marie-Antoine_Carême
# https://simple.wikipedia.org/wiki/Louise_Françoise_de_Bourbon,_Duchess_of_Bourbon
# https://simple.wikipedia.org/wiki/Cupa_României
# https://simple.wikipedia.org/wiki/Are_We_Not_Men?_We_Are_Devo!
# https://simple.wikipedia.org/wiki/Tomáš_Vokoun
# https://simple.wikipedia.org/wiki/Bahá'í_Faith
# https://simple.wikipedia.org/wiki/Napoléon_III
# https://simple.wikipedia.org/wiki/St._Croix_River_(Wisconsin–Minnesota)
# https://simple.wikipedia.org/wiki/Legendary_Pokémon
# https://simple.wikipedia.org/wiki/Darwin–Wallace_Medal
# https://simple.wikipedia.org/wiki/Bäriswil,_Bern
# https://simple.wikipedia.org/wiki/Marie_Thérèse_of_Austria
# https://simple.wikipedia.org/wiki/Manin
# https://simple.wikipedia.org/wiki/Pokémon
# https://simple.wikipedia.org/wiki/Howl's_Moving_Castle_(movie)
# https://simple.wikipedia.org/wiki/Legendary_Pokémon
# https://simple.wikipedia.org/wiki/23_(number)
# https://simple.wikipedia.org/wiki/Monkwearmouth–Jarrow_Abbey
# https://simple.wikipedia.org/wiki/Frédéric_Chopin
# https://simple.wikipedia.org/wiki/Blood–brain_barrier
# https://simple.wikipedia.org/wiki/Óscar_Pereiro
# https://simple.wikipedia.org/wiki/Tan_(color)
# https://simple.wikipedia.org/wiki/Pokémon
# https://simple.wikipedia.org/wiki/Père_David's_deer
# https://simple.wikipedia.org/wiki/German_National_People's_Party
# https://simple.wikipedia.org/wiki/Mexican–American_War
# https://simple.wikipedia.org/wiki/Dome-mae_Chiyozaki_Station
# https://simple.wikipedia.org/wiki/2011_Tōhoku_earthquake_and_tsunami
# https://simple.wikipedia.org/wiki/Uluṟu-Kata_Tjuṯa_National_Park
# https://simple.wikipedia.org/wiki/Pedro_Armendáriz,_Jr.
# https://simple.wikipedia.org/wiki/Deinococcus–Thermus
# https://simple.wikipedia.org/wiki/Teachta_Dála
# https://simple.wikipedia.org/wiki/Newton's_laws_of_motion
# https://simple.wikipedia.org/wiki/Gay_\u0026_Lesbian_Alliance_Against_Defamation
# https://simple.wikipedia.org/wiki/Clapper
# https://simple.wikipedia.org/wiki/Ceará_S.C.
# https://simple.wikipedia.org/wiki/Hundred_Years'_War
# https://simple.wikipedia.org/wiki/Christmas,_with_Love
# https://simple.wikipedia.org/wiki/New_Year's_Day
# https://simple.wikipedia.org/wiki/Robert_Blake_(actor)
# https://simple.wikipedia.org/wiki/Skeleton_key
# https://simple.wikipedia.org/wiki/My_Opposition:_The_Diaries_of_Friedrich_Kellner
# https://simple.wikipedia.org/wiki/Johnston's_African_dormouse
# https://simple.wikipedia.org/wiki/Christoph_Willibald_von_Gluck
# https://simple.wikipedia.org/wiki/Kōchi_Prefecture
# https://simple.wikipedia.org/wiki/Sinéad_O'Connor
# https://simple.wikipedia.org/wiki/Viktor_Orbán
# https://simple.wikipedia.org/wiki/René_Bourque
# https://simple.wikipedia.org/wiki/Sheremetev
# https://simple.wikipedia.org/wiki/Camille_Saint-Saëns
# https://simple.wikipedia.org/wiki/Kočevski_Rog_massacre
# https://simple.wikipedia.org/wiki/Châlons-en-Champagne
# https://simple.wikipedia.org/wiki/Lungless_salamanders
# https://simple.wikipedia.org/wiki/Provisional_government
# https://simple.wikipedia.org/wiki/Ürümqi
# https://simple.wikipedia.org/wiki/Joaquín_Guzmán
# https://simple.wikipedia.org/wiki/Horst_Köhler
# https://simple.wikipedia.org/wiki/Template_talk:Did_you_know
# https://simple.wikipedia.org/wiki/Ōtemachi_Station_(Tokyo)
# https://simple.wikipedia.org/wiki/Criciúma_E.C.
# https://simple.wikipedia.org/wiki/Women's_National_Basketball_Association
# https://simple.wikipedia.org/wiki/Nishinomiya,_Hyōgo
# https://simple.wikipedia.org/wiki/It_Won't_Be_Soon_Before_Long
# https://simple.wikipedia.org/wiki/Ariajasuru_Hasegawa
# https://simple.wikipedia.org/wiki/Vlorë
# https://simple.wikipedia.org/wiki/Abū_Rayḥān_al-Bīrūnī
# https://simple.wikipedia.org/wiki/Legendary_Pokémon
# https://simple.wikipedia.org/wiki/Miloš_Forman
# https://simple.wikipedia.org/wiki/Jérémie_Aliadière
# https://simple.wikipedia.org/wiki/Ryūkyū_Islands
# https://simple.wikipedia.org/wiki/École_pour_l'informatique_et_les_techniques_avancées
# https://simple.wikipedia.org/wiki/Shōkyō
# https://simple.wikipedia.org/wiki/Tate
# https://simple.wikipedia.org/wiki/Doge's_Palace,_Venice
# https://simple.wikipedia.org/wiki/Emerson,_Lake_\u0026_Palmer
# https://simple.wikipedia.org/wiki/A_Coruña_Province
# https://simple.wikipedia.org/wiki/Legendary_Pokémon
# https://simple.wikipedia.org/wiki/Saber–toothed_cat
# https://simple.wikipedia.org/wiki/Crosby,_Stills,_Nash_\u0026_Young
# https://simple.wikipedia.org/wiki/Neoarchaean
# https://simple.wikipedia.org/wiki/Kingdom_of_León
# https://simple.wikipedia.org/wiki/Wave–particle_duality
# https://simple.wikipedia.org/wiki/List_of_Presidents_of_Cuba
# https://simple.wikipedia.org/wiki/Pelé
# https://simple.wikipedia.org/wiki/Josef_Mysliveček
# https://simple.wikipedia.org/wiki/Alfredo_Di_Stéfano
# https://simple.wikipedia.org/wiki/Ba'athism
# https://simple.wikipedia.org/wiki/Earth's_mantle
# https://simple.wikipedia.org/wiki/Jaromír_Jágr
# https://simple.wikipedia.org/wiki/Pokémon
# https://simple.wikipedia.org/wiki/Network-attached_storage
# https://simple.wikipedia.org/wiki/Pokémon_Red_and_Blue
# https://simple.wikipedia.org/wiki/Cabannes
# https://simple.wikipedia.org/wiki/Saving_Abel_(2008_album)
# https://simple.wikipedia.org/wiki/Genkō_(era)
# https://simple.wikipedia.org/wiki/Ural_Mountains
# https://simple.wikipedia.org/wiki/Particulate
# https://simple.wikipedia.org/wiki/List_of_extinct_volcanoes
# https://simple.wikipedia.org/wiki/Valdez–Cordova_Census_Area,_Alaska
# https://simple.wikipedia.org/wiki/Andrés_Segovia
# https://simple.wikipedia.org/wiki/Thomas_Wyatt
# https://simple.wikipedia.org/wiki/Vestigial_organ
# https://simple.wikipedia.org/wiki/Simon_\u0026_Garfunkel
# https://simple.wikipedia.org/wiki/James_and_the_Giant_Peach_(movie)
# https://simple.wikipedia.org/wiki/Agent_Orange
# https://simple.wikipedia.org/wiki/Diego_Ramírez_Islands
# https://simple.wikipedia.org/wiki/New_Year's_Eve
# https://simple.wikipedia.org/wiki/Witch_doctor
# https://simple.wikipedia.org/wiki/François_Jacob
# https://simple.wikipedia.org/wiki/F.C._Steaua_Bucureşti
# https://simple.wikipedia.org/wiki/Simplicity
# https://simple.wikipedia.org/wiki/Galápagos_Islands
# https://simple.wikipedia.org/wiki/Mutual_assured_destruction
# https://simple.wikipedia.org/wiki/Schrödinger_equation
# https://simple.wikipedia.org/wiki/Ciarán_Hinds
# https://simple.wikipedia.org/wiki/'s-Hertogenbosch
# https://simple.wikipedia.org/wiki/1979–80_NHL_season
# https://simple.wikipedia.org/wiki/Humid_subtropical_climate
# https://simple.wikipedia.org/wiki/Charles-Maurice_de_Talleyrand-Périgord
# https://simple.wikipedia.org/wiki/Louis,_Duke_of_Burgundy
# https://simple.wikipedia.org/wiki/Pilica_(river)
# https://simple.wikipedia.org/wiki/Niccolò_Paganini
# https://simple.wikipedia.org/wiki/E=MC²_(album)
# https://simple.wikipedia.org/wiki/IFK_Göteborg
# https://simple.wikipedia.org/wiki/Grêmio_F.B.P.A.
# https://simple.wikipedia.org/wiki/Beyoncé_discography
# https://simple.wikipedia.org/wiki/Shakir_Ali
# https://simple.wikipedia.org/wiki/Guantánamo_Province
# https://simple.wikipedia.org/wiki/St._John's,_Newfoundland_and_Labrador
# https://simple.wikipedia.org/wiki/Pokémon
# https://simple.wikipedia.org/wiki/Miklós_Fehér
# https://simple.wikipedia.org/wiki/Frédéric_Chopin
# https://simple.wikipedia.org/wiki/João_Pessoa
# https://simple.wikipedia.org/wiki/Reinach,_Basel-Landschaft
# https://simple.wikipedia.org/wiki/Legendary_Pokémon
# https://simple.wikipedia.org/wiki/Mansfeld-Südharz_Rural_District
# https://simple.wikipedia.org/wiki/Musée_du_Louvre
# https://simple.wikipedia.org/wiki/Atlético_Madrid
# https://simple.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# https://simple.wikipedia.org/wiki/Wrocław
# https://simple.wikipedia.org/wiki/Cardinal_number
# https://simple.wikipedia.org/wiki/Zsa_Zsa_Gábor
# https://simple.wikipedia.org/wiki/January–February_2019_North_American_cold_wave
# https://simple.wikipedia.org/wiki/Marie_Thérèse_of_Austria
# https://simple.wikipedia.org/wiki/1810–1819_Atlantic_hurricane_seasons
# https://simple.wikipedia.org/wiki/Pimlico_tube_station
# https://simple.wikipedia.org/wiki/Torrent_salamander
# https://simple.wikipedia.org/wiki/Marley_\u0026_Me_(movie)
# https://simple.wikipedia.org/wiki/Hawker
# https://simple.wikipedia.org/wiki/Twice-cooked_pork
# https://simple.wikipedia.org/wiki/Idrissa_Ouédraogo
# https://simple.wikipedia.org/wiki/Côte_d'Ivoire
# https://simple.wikipedia.org/wiki/Céline_Dion
# https://simple.wikipedia.org/wiki/Legendary_Pokémon
# https://simple.wikipedia.org/wiki/Jorge_Batlle_Ibáñez
# https://simple.wikipedia.org/wiki/Estrildid_finch
# https://simple.wikipedia.org/wiki/Jorge_González
# https://simple.wikipedia.org/wiki/Father's_day
# https://simple.wikipedia.org/wiki/Earth's_core
# https://simple.wikipedia.org/wiki/Children's_literature
# https://simple.wikipedia.org/wiki/Eddie_Colón
# https://simple.wikipedia.org/wiki/WWE_Raw_Women's_Championship
# https://simple.wikipedia.org/wiki/Legendary_Pokémon
# https://simple.wikipedia.org/wiki/Szczecin_Lagoon
# https://simple.wikipedia.org/wiki/Brasília
# https://simple.wikipedia.org/wiki/Game_\u0026_Watch
# https://simple.wikipedia.org/wiki/Concepción
# https://simple.wikipedia.org/wiki/José_Napoleón_Duarte
# https://simple.wikipedia.org/wiki/Peer
# https://simple.wikipedia.org/wiki/Cancún
# https://simple.wikipedia.org/wiki/2010–11_NHL_season
# https://simple.wikipedia.org/wiki/Phạm_Duy
# https://simple.wikipedia.org/wiki/Cape_Lookout_(North_Carolina)
# https://simple.wikipedia.org/wiki/Ulyanovsk
# https://simple.wikipedia.org/wiki/Kalākaua
# https://simple.wikipedia.org/wiki/Milutin_Milanković
# https://simple.wikipedia.org/wiki/Maracanã_Stadium
# https://simple.wikipedia.org/wiki/Eyjafjallajökull
# https://simple.wikipedia.org/wiki/Mount_Clay
# https://simple.wikipedia.org/wiki/Shōchō
# https://simple.wikipedia.org/wiki/Dadikai_languages
# https://simple.wikipedia.org/wiki/Dunière-sur-Eyrieux
# https://simple.wikipedia.org/wiki/Pokémon_Red_and_Blue
# https://simple.wikipedia.org/wiki/1978–79_NHL_season
# https://simple.wikipedia.org/wiki/Netscape_Navigator
# https://simple.wikipedia.org/wiki/Girls'_Generation
# https://simple.wikipedia.org/wiki/Pallas'_cat
# https://simple.wikipedia.org/wiki/Yolanda_Saldívar
# https://simple.wikipedia.org/wiki/Caro–Kann_defence
# https://simple.wikipedia.org/wiki/Brassière
# https://simple.wikipedia.org/wiki/São_Tomé_and_Príncipe
# https://simple.wikipedia.org/wiki/National_Assembly_(France)
# https://simple.wikipedia.org/wiki/Asunción
# https://simple.wikipedia.org/wiki/Following
# https://simple.wikipedia.org/wiki/Common_barn_owl
# https://simple.wikipedia.org/wiki/Tonka_Tomičić
# https://simple.wikipedia.org/wiki/Hercules_(1958_movie)
# https://simple.wikipedia.org/wiki/Marie_Émilie_de_Joly_de_Choin
# https://simple.wikipedia.org/wiki/Lars_Løkke_Rasmussen
# https://simple.wikipedia.org/wiki/UTC+01:00
# https://simple.wikipedia.org/wiki/Grand_duchy
# https://simple.wikipedia.org/wiki/El_Niño–Southern_Oscillation
# https://simple.wikipedia.org/wiki/Hérault
# https://simple.wikipedia.org/wiki/Diego_Velázquez_de_Cuéllar
# https://simple.wikipedia.org/wiki/2015–16_NHL_season
# https://simple.wikipedia.org/wiki/Sea_Peoples
# https://simple.wikipedia.org/wiki/Socialist_Left_Party
# https://simple.wikipedia.org/wiki/Mexican–American_War
# https://simple.wikipedia.org/wiki/Diego_Velázquez
# https://simple.wikipedia.org/wiki/Oberallgäu
# https://simple.wikipedia.org/wiki/2002–03_UEFA_Cup
# https://simple.wikipedia.org/wiki/Comet_Group
# https://simple.wikipedia.org/wiki/Jörmungandr
# https://simple.wikipedia.org/wiki/Béchamel_sauce
# https://simple.wikipedia.org/wiki/Communes_of_Romania
# https://simple.wikipedia.org/wiki/Bifröst
# https://simple.wikipedia.org/wiki/Comet_Shoemaker–Levy_9
# https://simple.wikipedia.org/wiki/María_Capovilla
# https://simple.wikipedia.org/wiki/Ángel_Di_Maria
# https://simple.wikipedia.org/wiki/Søren_Kierkegaard
# https://simple.wikipedia.org/wiki/UTC−03:00
# https://simple.wikipedia.org/wiki/Nēnē
# https://simple.wikipedia.org/wiki/Blue_Öyster_Cult
# https://simple.wikipedia.org/wiki/Jehovah's_Witnesses
# https://simple.wikipedia.org/wiki/2012–13_NHL_season
# https://simple.wikipedia.org/wiki/Zürich
# https://simple.wikipedia.org/wiki/Legendary_Pokémon
# https://simple.wikipedia.org/wiki/Les_Misérables
# https://simple.wikipedia.org/wiki/Pokémon
# https://simple.wikipedia.org/wiki/Camille_Saint-Saëns
# https://simple.wikipedia.org/wiki/Joint_Base_Pearl_Harbor–Hickam
# https://simple.wikipedia.org/wiki/Pearl_Carr_\u0026_Teddy_Johnson
# https://simple.wikipedia.org/wiki/Mory
# https://simple.wikipedia.org/wiki/Cassini–Huygens
# https://simple.wikipedia.org/wiki/Province_of_Forlì-Cesena
# https://simple.wikipedia.org/wiki/Comet_Hale–Bopp
# https://simple.wikipedia.org/wiki/Phở
# https://simple.wikipedia.org/wiki/Gustave_Doré
# https://simple.wikipedia.org/wiki/Kyōroku
# https://simple.wikipedia.org/wiki/Financial_crisis_of_2007–2008
# https://simple.wikipedia.org/wiki/Kunstakademie_Düsseldorf
# https://simple.wikipedia.org/wiki/Greatest_Hits
# https://simple.wikipedia.org/wiki/Horst_Köhler
# https://simple.wikipedia.org/wiki/Saber–toothed_cat
# https://simple.wikipedia.org/wiki/Gorgonopsid
# https://simple.wikipedia.org/wiki/Hérault
# https://simple.wikipedia.org/wiki/Mantophasmatidae
# https://simple.wikipedia.org/wiki/Jim_Jeffords
# https://simple.wikipedia.org/wiki/Simon_\u0026_Schuster
# https://simple.wikipedia.org/wiki/Vapor
# https://simple.wikipedia.org/wiki/Souq
# https://simple.wikipedia.org/wiki/Kobe,_Hyōgo
# https://simple.wikipedia.org/wiki/Samaná_English
# https://simple.wikipedia.org/wiki/Béla_Bartók
# https://simple.wikipedia.org/wiki/First_Jewish–Roman_War
# https://simple.wikipedia.org/wiki/Death's-head_hawkmoth
# https://simple.wikipedia.org/wiki/Ferdinand_Philippe,_Duke_of_Orléans
# https://simple.wikipedia.org/wiki/Interlingue
# https://simple.wikipedia.org/wiki/Jehovah's_Witnesses
# https://simple.wikipedia.org/wiki/René_Descartes
# https://simple.wikipedia.org/wiki/Détente
# https://simple.wikipedia.org/wiki/St._Peter's_Basilica
# https://simple.wikipedia.org/wiki/1983–84_NHL_season
# https://simple.wikipedia.org/wiki/Marco_Rubio_2016_presidential_campaign
# https://simple.wikipedia.org/wiki/Creutzfeldt–Jakob_disease
# https://simple.wikipedia.org/wiki/Physiotherapy
# https://simple.wikipedia.org/wiki/Emerson,_Lake_\u0026_Palmer
# https://simple.wikipedia.org/wiki/The_Greens_–_The_Green_Alternative
# ...
# https://simple.wikipedia.org/wiki/Santo_Monti
# https://simple.wikipedia.org/wiki/National_Hockey_League_Players'_Association
# https://simple.wikipedia.org/wiki/Barnum's_American_Museum
# https://simple.wikipedia.org/wiki/Sant_Ravidas_Nagar_district
# https://simple.wikipedia.org/wiki/Symphony_No._9_\
# https://simple.wikipedia.org/wiki/Marie_Anne_Éléonore_de_Bourbon
# https://simple.wikipedia.org/wiki/Fenerbahçe_S.K.
# https://simple.wikipedia.org/wiki/Template:Did_you_know/Queue/6
# https://simple.wikipedia.org/wiki/Sadler's_Wells_Theatre
# https://simple.wikipedia.org/wiki/Leandro_Euzébio
# https://simple.wikipedia.org/wiki/Salam
# https://simple.wikipedia.org/wiki/I'm_a_Celebrity...Get_Me_Out_of_Here!
# https://simple.wikipedia.org/wiki/Beşiktaş_J.K.
# https://simple.wikipedia.org/wiki/Peasants'_Revolt
# https://simple.wikipedia.org/wiki/SS-Verfügungstruppe
# https://simple.wikipedia.org/wiki/Rodrigo_García
# https://simple.wikipedia.org/wiki/Mthatha
# https://simple.wikipedia.org/wiki/Gardēz
# https://simple.wikipedia.org/wiki/Beauvau_family
# https://simple.wikipedia.org/wiki/CS_Pandurii_Târgu_Jiu
# https://simple.wikipedia.org/wiki/Harbor_seal
# https://simple.wikipedia.org/wiki/Béla_Lugosi
# https://simple.wikipedia.org/wiki/1957–58_Eerste_Divisie
# https://simple.wikipedia.org/wiki/Bill_O'Reilly
# https://simple.wikipedia.org/wiki/Paul_Cézanne
# https://simple.wikipedia.org/wiki/Frozen_dinner
# https://simple.wikipedia.org/wiki/Weißwasser
# https://simple.wikipedia.org/wiki/Déjà_Vu_(song)
# https://simple.wikipedia.org/wiki/Game_Boy_line
# https://simple.wikipedia.org/wiki/Stonemasonry
# https://simple.wikipedia.org/wiki/Can't_Be_Tamed
# https://simple.wikipedia.org/wiki/José_Figueres_Ferrer
# https://simple.wikipedia.org/wiki/Luis_Carlos_Galán
# https://simple.wikipedia.org/wiki/Carpenter
# https://simple.wikipedia.org/wiki/Geospatial_Information_Authority_of_Japan
# https://simple.wikipedia.org/wiki/Vuelta_Ciclista_a_España
# https://simple.wikipedia.org/wiki/Iron(II,III)_oxide
# https://simple.wikipedia.org/wiki/Frugality
# https://simple.wikipedia.org/wiki/Plain_White_T's
# https://simple.wikipedia.org/wiki/Dacarbazine
# https://simple.wikipedia.org/wiki/Pachelbel's_Canon
# https://simple.wikipedia.org/wiki/Jet_Propulsion_Laboratory
# https://simple.wikipedia.org/wiki/La_Tène_culture
# https://simple.wikipedia.org/wiki/Never_Mind_the_Bollocks,_Here's_the_Sex_Pistols
# https://simple.wikipedia.org/wiki/Hootie_\u0026_the_Blowfish
# https://simple.wikipedia.org/wiki/2010–11_Manchester_United_F.C._season
# https://simple.wikipedia.org/wiki/CS_Pandurii_Târgu_Jiu
# https://simple.wikipedia.org/wiki/León,_Spain
# https://simple.wikipedia.org/wiki/Molière
# https://simple.wikipedia.org/wiki/Argeș_River
# https://simple.wikipedia.org/wiki/Galápagos_penguin
# https://simple.wikipedia.org/wiki/Orange-breasted_sunbird
# https://simple.wikipedia.org/wiki/Universitat_d'Andorra
# https://simple.wikipedia.org/wiki/Paedophryne
# https://simple.wikipedia.org/wiki/Sinners_in_the_Hands_of_an_Angry_God
# https://simple.wikipedia.org/wiki/Nelumbo
# https://simple.wikipedia.org/wiki/Ruble
# https://simple.wikipedia.org/wiki/Co-factor
# https://simple.wikipedia.org/wiki/León,_Spain
# https://simple.wikipedia.org/wiki/C.A._Peñarol
# https://simple.wikipedia.org/wiki/Engraving
# https://simple.wikipedia.org/wiki/Same-sex_relationship
# https://simple.wikipedia.org/wiki/Wikipedia:Basic_English_combined_wordlist
# https://simple.wikipedia.org/wiki/Pokémon_crime_organizations
# https://simple.wikipedia.org/wiki/Music_session
# https://simple.wikipedia.org/wiki/Pokémon
# https://simple.wikipedia.org/wiki/Daniela_Hantuchová
# https://simple.wikipedia.org/wiki/Minnesota_Democratic–Farmer–Labor_Party
# https://simple.wikipedia.org/wiki/Ferdinando_II_de'_Medici,_Grand_Duke_of_Tuscany
# https://simple.wikipedia.org/wiki/August_Ferdinand_Möbius
# https://simple.wikipedia.org/wiki/1._FC_Saarbrücken
# https://simple.wikipedia.org/wiki/Rüti,_Zürich
# https://simple.wikipedia.org/wiki/Fingal’s_Cave
# https://simple.wikipedia.org/wiki/Vibrio
# https://simple.wikipedia.org/wiki/1970–71_NHL_season
# https://simple.wikipedia.org/wiki/First_Lieutenant
# https://simple.wikipedia.org/wiki/What's_My_Name?
# https://simple.wikipedia.org/wiki/Chloë_Moretz
# https://simple.wikipedia.org/wiki/Percy_Jackson_\u0026_the_Olympians
# https://simple.wikipedia.org/wiki/Heckler_\u0026_Koch_MP_series
# https://simple.wikipedia.org/wiki/Angels_\u0026_Demons
# https://simple.wikipedia.org/wiki/Petén_Department
# https://simple.wikipedia.org/wiki/Mandé_people
# https://simple.wikipedia.org/wiki/Văn_Cao
# https://simple.wikipedia.org/wiki/Séléka
# https://simple.wikipedia.org/wiki/Fishery
# https://simple.wikipedia.org/wiki/Milton_S._Hershey
# https://simple.wikipedia.org/wiki/Obsessive–compulsive_disorder
# https://simple.wikipedia.org/wiki/Bunker
# https://simple.wikipedia.org/wiki/Dadikai_languages
# https://simple.wikipedia.org/wiki/Mojang
# https://simple.wikipedia.org/wiki/Comăneşti,_Suceava
# https://simple.wikipedia.org/wiki/Jötnar
# https://simple.wikipedia.org/wiki/Symphony_No._9_\
# https://simple.wikipedia.org/wiki/Oviparous_animals
# https://simple.wikipedia.org/wiki/Hafiz_(Qur'an)
# https://simple.wikipedia.org/wiki/Home_page
# https://simple.wikipedia.org/wiki/Judit_Polgár
# https://simple.wikipedia.org/wiki/Death's-head_hawkmoth
# https://simple.wikipedia.org/wiki/Przewalski's_horse
# https://simple.wikipedia.org/wiki/Tassili_n'Ajjer
# https://simple.wikipedia.org/wiki/All_Saints'_Day
# https://simple.wikipedia.org/wiki/Mihai_Răzvan_Ungureanu
# https://simple.wikipedia.org/wiki/Let's_Play
# https://simple.wikipedia.org/wiki/Emerson,_Lake_\u0026_Palmer
# https://simple.wikipedia.org/wiki/Cosimo_III_de'_Medici,_Grand_Duke_of_Tuscany
# https://simple.wikipedia.org/wiki/Room_Service
# https://simple.wikipedia.org/wiki/Crash_Holly
# https://simple.wikipedia.org/wiki/Tom_Clancy's_Rainbow_Six:_Vegas_2
# https://simple.wikipedia.org/wiki/Saint_Catherine's_Monastery
# https://simple.wikipedia.org/wiki/2014–15_Bundesliga_(women)
# https://simple.wikipedia.org/wiki/Nazirite
# https://simple.wikipedia.org/wiki/Opéra-Comique
# https://simple.wikipedia.org/wiki/Lowell_P._Weicker,_Jr.
# https://simple.wikipedia.org/wiki/DIY
# https://simple.wikipedia.org/wiki/Scholz's_Star
# https://simple.wikipedia.org/wiki/Réaumur_scale
# https://simple.wikipedia.org/wiki/Severan_dynasty
# https://simple.wikipedia.org/wiki/André_the_Giant
# https://simple.wikipedia.org/wiki/Gríðr
# https://simple.wikipedia.org/wiki/Quantum_theory
# https://simple.wikipedia.org/wiki/Railway_track
# https://simple.wikipedia.org/wiki/N'dalatando
# https://simple.wikipedia.org/wiki/Line_1_Yonge–University
# https://simple.wikipedia.org/wiki/Severan_dynasty
# https://simple.wikipedia.org/wiki/Toys_\
# https://simple.wikipedia.org/wiki/Bikont
# https://simple.wikipedia.org/wiki/Inner_ear
# https://simple.wikipedia.org/wiki/Parkinson's_disease
# https://simple.wikipedia.org/wiki/Philippe_Égalité
# https://simple.wikipedia.org/wiki/Aquatic_plant
# https://simple.wikipedia.org/wiki/Prediction
# https://simple.wikipedia.org/wiki/Pop
# https://simple.wikipedia.org/wiki/Álvaro_Uribe
# https://simple.wikipedia.org/wiki/U.S._Open
# https://simple.wikipedia.org/wiki/The_Sorcerer's_Apprentice_(2010_movie)
# https://simple.wikipedia.org/wiki/Poll_tax
# https://simple.wikipedia.org/wiki/Intimacy
# https://simple.wikipedia.org/wiki/Emperor_Kōshō
# https://simple.wikipedia.org/wiki/The_Dong-a_Ilbo
# https://simple.wikipedia.org/wiki/Barcelona_Metro_line_2
# https://simple.wikipedia.org/wiki/Methane_hydrate
# https://simple.wikipedia.org/wiki/Egocentrism
# https://simple.wikipedia.org/wiki/Logroño
# https://simple.wikipedia.org/wiki/Wikipedia:GLAM/MonmouthpediA
# https://simple.wikipedia.org/wiki/Huế
# https://simple.wikipedia.org/wiki/Ted_Phillips
# https://simple.wikipedia.org/wiki/Serviciul_Român_de_Informaţii
# https://simple.wikipedia.org/wiki/Ja'far
# https://simple.wikipedia.org/wiki/RM4SCC
# https://simple.wikipedia.org/wiki/Jin_dynasty
# https://simple.wikipedia.org/wiki/Diogenes_Laërtius
# https://simple.wikipedia.org/wiki/Chuy_García
# https://simple.wikipedia.org/wiki/Appellation_d'origine_contrôlée
# https://simple.wikipedia.org/wiki/Princess_Sofia,_Duchess_of_Värmland
# https://simple.wikipedia.org/wiki/Tabaré_Vázquez
# https://simple.wikipedia.org/wiki/São_Bernardo_do_Campo
# https://simple.wikipedia.org/wiki/Pokémon
# https://simple.wikipedia.org/wiki/Emerson,_Lake_\u0026_Palmer
# https://simple.wikipedia.org/wiki/Düsseldorf
# https://simple.wikipedia.org/wiki/Cancuén
# https://simple.wikipedia.org/wiki/Serene_Highness
# https://simple.wikipedia.org/wiki/Canton_of_Zürich
# https://simple.wikipedia.org/wiki/Cox's_Bazar
# https://simple.wikipedia.org/wiki/San_Sebastián
# https://simple.wikipedia.org/wiki/Kantō_region
# https://simple.wikipedia.org/wiki/Jewish–Roman_wars
# https://simple.wikipedia.org/wiki/United_States_Census
# https://simple.wikipedia.org/wiki/Jin_dynasty
# https://simple.wikipedia.org/wiki/Raúl_Alfonsín
# https://simple.wikipedia.org/wiki/Francesco_Maria_de'_Medici
# https://simple.wikipedia.org/wiki/Denticle_(teeth)
# https://simple.wikipedia.org/wiki/Nolan_Ryan
# https://simple.wikipedia.org/wiki/Alzheimer's_disease
# https://simple.wikipedia.org/wiki/Ranma_½
# https://simple.wikipedia.org/wiki/Marie_Louise_of_Orléans_(1662–1689)
# https://simple.wikipedia.org/wiki/Hell's_Kitchen,_Manhattan
# https://simple.wikipedia.org/wiki/OMF_International
# https://simple.wikipedia.org/wiki/Drake_\u0026_Josh
# https://simple.wikipedia.org/wiki/Falsifiability
# https://simple.wikipedia.org/wiki/Autódromo_José_Carlos_Pace
# https://simple.wikipedia.org/wiki/Estée_Lauder
# https://simple.wikipedia.org/wiki/Béchamel_sauce
# https://simple.wikipedia.org/wiki/Fenerbahçe_S.K.
# https://simple.wikipedia.org/wiki/Sergio_Escudero
# https://simple.wikipedia.org/wiki/Visegrád_Group
# https://simple.wikipedia.org/wiki/Castellón_Province
# https://simple.wikipedia.org/wiki/Johann_Friedrich_Franz_Burgmüller
# https://simple.wikipedia.org/wiki/Champagne
# https://simple.wikipedia.org/wiki/Djurgårdens_I.F.
# https://simple.wikipedia.org/wiki/Pyrénées-Orientales
# https://simple.wikipedia.org/wiki/Geo/Chevrolet_Prizm
# https://simple.wikipedia.org/wiki/Jérôme_d'Ambrosio
# https://simple.wikipedia.org/wiki/Carrier_sense_multiple_access
# https://simple.wikipedia.org/wiki/Avery–MacLeod–McCarty_experiment
# https://simple.wikipedia.org/wiki/Nissan_Stadium
# https://simple.wikipedia.org/wiki/ECW_World_Heavyweight_Championship
# https://simple.wikipedia.org/wiki/Elsa_Einstein
# https://simple.wikipedia.org/wiki/Area_codes_in_Germany
# https://simple.wikipedia.org/wiki/Bradyon
# https://simple.wikipedia.org/wiki/'s-Hertogenbosch
# https://simple.wikipedia.org/wiki/Grand_duchy
# https://simple.wikipedia.org/wiki/Māori
# https://simple.wikipedia.org/wiki/Prince_of_Wales_Island_(Nunavut)
# https://simple.wikipedia.org/wiki/George_Müller
# https://simple.wikipedia.org/wiki/Queens'_College,_Cambridge
# https://simple.wikipedia.org/wiki/Caló
# https://simple.wikipedia.org/wiki/Eighty_Years'_War
# https://simple.wikipedia.org/wiki/Temporal_bone
# https://simple.wikipedia.org/wiki/UEFA_Women's_Champions_League
# https://simple.wikipedia.org/wiki/Günter_Grass
# https://simple.wikipedia.org/wiki/UniMás
# https://simple.wikipedia.org/wiki/Puerto_Cabezas
# https://simple.wikipedia.org/wiki/Tiësto
# https://simple.wikipedia.org/wiki/Rectifier
# https://simple.wikipedia.org/wiki/Fibre-reinforced_polymer
# https://simple.wikipedia.org/wiki/Femininity
# https://simple.wikipedia.org/wiki/Žydrūnas_Ilgauskas
# https://simple.wikipedia.org/wiki/Symphony_No._94_\
# https://simple.wikipedia.org/wiki/Rubik's_Cube
# https://simple.wikipedia.org/wiki/Stoke-by-Clare
# https://simple.wikipedia.org/wiki/Intimacy
# https://simple.wikipedia.org/wiki/Sköll
# https://simple.wikipedia.org/wiki/Narsingdi_District
# https://simple.wikipedia.org/wiki/Emerson,_Lake_\u0026_Palmer
# https://simple.wikipedia.org/wiki/Log_cabin
# https://simple.wikipedia.org/wiki/McDonald's
# https://simple.wikipedia.org/wiki/Françoise_d'Aubigné,_Marquise_de_Maintenon
# https://simple.wikipedia.org/wiki/Fleur_de_lys
# https://simple.wikipedia.org/wiki/André_the_Giant
# https://simple.wikipedia.org/wiki/Córdoba,_Argentina
# https://simple.wikipedia.org/wiki/Coup_d'état
# https://simple.wikipedia.org/wiki/Ableism
# https://simple.wikipedia.org/wiki/Aesch,_Zürich
# https://simple.wikipedia.org/wiki/St._Paul's_Cathedral
# https://simple.wikipedia.org/wiki/Soufflé
# https://simple.wikipedia.org/wiki/Sergio_Pérez
# https://simple.wikipedia.org/wiki/Genesis_Nomad
# https://simple.wikipedia.org/wiki/Arara,_Paraíba
# https://simple.wikipedia.org/wiki/Fátima,_Portugal
# https://simple.wikipedia.org/wiki/Żabbar
# https://simple.wikipedia.org/wiki/Ouch
# https://simple.wikipedia.org/wiki/Luis_Gutiérrez
# https://simple.wikipedia.org/wiki/Blood,_Sweat_\u0026_Tears
# https://simple.wikipedia.org/wiki/Ryūjin
# https://simple.wikipedia.org/wiki/Newton_metre
# https://simple.wikipedia.org/wiki/Vuelta_Ciclista_a_España
# https://simple.wikipedia.org/wiki/Dungeons_\u0026_Dragons
# https://simple.wikipedia.org/wiki/Grimms'_Fairy_Tales
# https://simple.wikipedia.org/wiki/MERS
# https://simple.wikipedia.org/wiki/Donde_Quiera_Que_Estés
# https://simple.wikipedia.org/wiki/Brigadier_general
# https://simple.wikipedia.org/wiki/Roberto_Eduardo_Viola
# https://simple.wikipedia.org/wiki/North–South_divide
# https://simple.wikipedia.org/wiki/Hokkaidō
# https://simple.wikipedia.org/wiki/Röyksopp
# https://simple.wikipedia.org/wiki/Commensurability
# https://simple.wikipedia.org/wiki/Gulfport-Biloxi-Pascagoula,_Mississippi_Combined_Statistical_Area
# https://simple.wikipedia.org/wiki/Reel-to-reel_tape_recorders
# https://simple.wikipedia.org/wiki/Aşgabat
# https://simple.wikipedia.org/wiki/Córdoba_Province_(Spain)
# https://simple.wikipedia.org/wiki/Domino's_Pizza
# https://simple.wikipedia.org/wiki/65_(number)
# https://simple.wikipedia.org/wiki/Ferdinando_II_de'_Medici,_Grand_Duke_of_Tuscany
# https://simple.wikipedia.org/wiki/Niqāb
# https://simple.wikipedia.org/wiki/Night_terror
# https://simple.wikipedia.org/wiki/Drop_goal
# https://simple.wikipedia.org/wiki/Domino's_Pizza
# https://simple.wikipedia.org/wiki/Groupement_des_industries_françaises_aéronautiques_et_spatiales
# https://simple.wikipedia.org/wiki/Hansō_Sōshitsu
# https://simple.wikipedia.org/wiki/2012_London_mayoral_election
# https://simple.wikipedia.org/wiki/Nēnē
# https://simple.wikipedia.org/wiki/Rimouski_Océanic
# https://simple.wikipedia.org/wiki/Aristide_Cavaillé-Coll
# https://simple.wikipedia.org/wiki/Münchausen_syndrome
# https://simple.wikipedia.org/wiki/ʻIolani_Palace
# https://simple.wikipedia.org/wiki/Barcelona_Metro_line_6
# https://simple.wikipedia.org/wiki/Kazimierz_Świątek
# https://simple.wikipedia.org/wiki/Hertzsprung–Russell_diagram
# https://simple.wikipedia.org/wiki/Closed_source
# https://simple.wikipedia.org/wiki/Nuss_Procedure
# https://simple.wikipedia.org/wiki/Leonese_Language_Day
# https://simple.wikipedia.org/wiki/Railway_track
# https://simple.wikipedia.org/wiki/Qaumī_Tarāna
# https://simple.wikipedia.org/wiki/Driver's_license
# https://simple.wikipedia.org/wiki/Hall_\u0026_Oates
# https://simple.wikipedia.org/wiki/Iván_Rodríguez
# https://simple.wikipedia.org/wiki/Emme
# https://simple.wikipedia.org/wiki/King's_Cross_station
# https://simple.wikipedia.org/wiki/64_(number)
# https://simple.wikipedia.org/wiki/Earth,_Wind_\u0026_Fire
# https://simple.wikipedia.org/wiki/Mechanically_powered_torch
# https://simple.wikipedia.org/wiki/Philosophiæ_Naturalis_Principia_Mathematica
# https://simple.wikipedia.org/wiki/Scorpius–Centaurus_Association
# https://simple.wikipedia.org/wiki/Xbox_Game_Studios
# https://simple.wikipedia.org/wiki/Sankt_Pölten
# https://simple.wikipedia.org/wiki/Blue_Öyster_Cult
# https://simple.wikipedia.org/wiki/İzmir
# https://simple.wikipedia.org/wiki/Blue_Öyster_Cult
# https://simple.wikipedia.org/wiki/Blue_Öyster_Cult
# https://simple.wikipedia.org/wiki/VLC_media_player
# https://simple.wikipedia.org/wiki/Mayor–council_government
# https://simple.wikipedia.org/wiki/Hectosecond
# https://simple.wikipedia.org/wiki/Ed_and_Lorraine_Warren
# https://simple.wikipedia.org/wiki/Florida's_Turnpike
# https://simple.wikipedia.org/wiki/Zezë
# https://simple.wikipedia.org/wiki/Crosby,_Stills,_Nash_\u0026_Young
# https://simple.wikipedia.org/wiki/Integer_overflow

# %%
len(file_storage_without_redirects)
# Out:
# 168476

# %% [markdown]
# Получается, если считать категории статьями - выходит много, а если нет - мало)
# В любом случае, не знаю что еще можно убрать.
