# %%
import urllib
import requests

# %%
from urllib.parse import urlparse
from urllib.parse import urldefrag
import time

# %%
from urllib.request import urlopen

def download_from_the_internet(url):
    try:
        return urlopen(url).read().decode('utf-8')
    except KeyboardInterrupt:
        raise
    except Exception as e:
        print(e)

start_url = 'https://simple.wikipedia.org/wiki/Main_Page'

# %%
from file_storage import FileStorage

file_storage = FileStorage('storage')

# %%
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def extract_links_from_html(url, html):
    parser = BeautifulSoup(html)
    return [urljoin(url, link.get('href')) for link in parser.findAll('a')]

# %%
import pickle
state_file_path = 'state.pickle'

def dump_state(iteration, urls_to_visit):
    with open(state_file_path, 'wb') as state_file:
        pickle.dump((iteration, urls_to_visit), state_file)
        print('state saved, iteration {}'.format(iteration))

def load_state():
    with open(state_file_path, 'rb') as state_file:
        return pickle.load(state_file)

# %%
urls_to_visit = {start_url}
iteration = 0

# %%
beginning = 'https://simple.wikipedia.org/wiki/'

def filter_url(url):
    if not url.startswith(beginning):
        return True
    url_end = url[len(beginning):]
    return any(url_end.startswith(ban_pattern) for ban_pattern in ban_patterns)

# %%
from multiprocessing.pool import Pool

# %%
import os
cpu_count = os.cpu_count()

# %%
import requests
from lxml.html import fromstring
from itertools import cycle

def get_proxy_pools():
    url = 'https://free-proxy-list.net/'
    response = requests.get(url)
    parser = fromstring(response.text)
    proxies = set()
    for i in parser.xpath('//tbody/tr'):
        if i.xpath('.//td[7][contains(text(),"yes")]'):
            #Grabbing IP and corresponding PORT
            proxy = ":".join([i.xpath('.//td[1]/text()')[0], i.xpath('.//td[2]/text()')[0]])
            proxies.add(proxy)
    proxies = list(proxies)
    proxy_pools = {
        i: cycle(proxies[i::cpu_count])
        for i in range(cpu_count)
    }
    return proxy_pools

# %%
ban_patterns = ['Help', 'Wikipedia', 'Special', 'File', 'Template', 'Talk', 'Template_talk', 'User_talk']
ban_patterns = [pattern + ':' for pattern in ban_patterns]

def parse_url(url):
    for attempt in range(2):
        html = download_from_the_internet(url)
        time.sleep(0.2)
        if html is not None:
            break
    else:
        return None

    urls = extract_links_from_html(url, html)
    return url, html, urls

def download_wiki(iteration, urls_to_visit, need_log=False):
    results = []
    with Pool() as pool:
        while urls_to_visit or results:
            new_url = urls_to_visit.pop()
            results.append(pool.apply_async(parse_url, (new_url,)))
            for ind, result in enumerate(results):
                if result.ready():
                    completed_result = result.get()
                    results.pop(ind)
                    break
            else:
                if len(results) < cpu_count - 1:
                    continue
                else:
                    completed_result = results[0].get()
                    results.pop(0)
            if completed_result is None:
                continue
            new_url, new_html, new_urls = completed_result
            file_storage.write(new_url, new_html)
                
            fresh_urls = [
                urldefrag(url).url
                for url in new_urls
                if url not in file_storage and not filter_url(urldefrag(url).url)
            ]
            urls_to_visit.update(fresh_urls)
            iteration += 1
            if iteration % 10 == 0:
                dump_state(iteration, urls_to_visit)

# %%
iteration, urls_to_visit = load_state()
download_wiki(iteration, urls_to_visit, need_log=False)
# Out:
# state saved, iteration 120820
# state saved, iteration 120830
# state saved, iteration 120840
# state saved, iteration 120850
# state saved, iteration 120860
# state saved, iteration 120870
# state saved, iteration 120880
# state saved, iteration 120890
# state saved, iteration 120900
# state saved, iteration 120910
# state saved, iteration 120920
# state saved, iteration 120930
# state saved, iteration 120940
# state saved, iteration 120950
# state saved, iteration 120960
# HTTP Error 404: Not Found
# state saved, iteration 120970
# HTTP Error 404: Not Found
# state saved, iteration 120980
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# state saved, iteration 120990
# state saved, iteration 121000
# state saved, iteration 121010
# state saved, iteration 121020
# state saved, iteration 121030
# state saved, iteration 121040
# state saved, iteration 121050
# state saved, iteration 121060
# state saved, iteration 121070
# state saved, iteration 121080
# state saved, iteration 121090
# state saved, iteration 121100
# state saved, iteration 121110
# state saved, iteration 121120
# state saved, iteration 121130
# state saved, iteration 121140
# state saved, iteration 121150
# state saved, iteration 121160
# state saved, iteration 121170
# state saved, iteration 121180
# state saved, iteration 121190
# state saved, iteration 121200
# state saved, iteration 121210
# state saved, iteration 121220
# state saved, iteration 121230
# state saved, iteration 121240
# state saved, iteration 121250
# state saved, iteration 121260
# state saved, iteration 121270
# state saved, iteration 121280
# state saved, iteration 121290
# state saved, iteration 121300
# state saved, iteration 121310
# state saved, iteration 121320
# state saved, iteration 121330
# state saved, iteration 121340
# state saved, iteration 121350
# state saved, iteration 121360
# state saved, iteration 121370
# state saved, iteration 121380
# state saved, iteration 121390
# state saved, iteration 121400
# state saved, iteration 121410
# state saved, iteration 121420
# state saved, iteration 121430
# state saved, iteration 121440
# state saved, iteration 121450
# state saved, iteration 121460
# state saved, iteration 121470
# state saved, iteration 121480
# state saved, iteration 121490
# state saved, iteration 121500
# state saved, iteration 121510
# state saved, iteration 121520
# state saved, iteration 121530
# state saved, iteration 121540
# state saved, iteration 121550
# state saved, iteration 121560
# state saved, iteration 121570
# state saved, iteration 121580
# state saved, iteration 121590
# state saved, iteration 121600
# state saved, iteration 121610
# state saved, iteration 121620
# state saved, iteration 121630
# state saved, iteration 121640
# state saved, iteration 121650
# state saved, iteration 121660
# state saved, iteration 121670
# state saved, iteration 121680
# state saved, iteration 121690
# state saved, iteration 121700
# state saved, iteration 121710
# state saved, iteration 121720
# state saved, iteration 121730
# state saved, iteration 121740
# state saved, iteration 121750
# state saved, iteration 121760
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# state saved, iteration 121770
# state saved, iteration 121780
# state saved, iteration 121790
# state saved, iteration 121800
# state saved, iteration 121810
# state saved, iteration 121820
# state saved, iteration 121830
# state saved, iteration 121840
# state saved, iteration 121850
# state saved, iteration 121860
# state saved, iteration 121870
# state saved, iteration 121880
# state saved, iteration 121890
# state saved, iteration 121900
# state saved, iteration 121910
# state saved, iteration 121920
# state saved, iteration 121930
# state saved, iteration 121940
# state saved, iteration 121950
# state saved, iteration 121960
# state saved, iteration 121970
# state saved, iteration 121980
# state saved, iteration 121990
# state saved, iteration 122000
# state saved, iteration 122010
# state saved, iteration 122020
# state saved, iteration 122030
# state saved, iteration 122040
# state saved, iteration 122050
# state saved, iteration 122060
# state saved, iteration 122070
# state saved, iteration 122080
# state saved, iteration 122090
# state saved, iteration 122100
# state saved, iteration 122110
# state saved, iteration 122120
# state saved, iteration 122130
# state saved, iteration 122140
# state saved, iteration 122150
# state saved, iteration 122160
# state saved, iteration 122170
# state saved, iteration 122180
# state saved, iteration 122190
# state saved, iteration 122200
# state saved, iteration 122210
# state saved, iteration 122220
# state saved, iteration 122230
# state saved, iteration 122240
# state saved, iteration 122250
# state saved, iteration 122260
# state saved, iteration 122270
# state saved, iteration 122280
# state saved, iteration 122290
# state saved, iteration 122300
# state saved, iteration 122310
# state saved, iteration 122320
# state saved, iteration 122330
# state saved, iteration 122340
# state saved, iteration 122350
# state saved, iteration 122360
# state saved, iteration 122370
# state saved, iteration 122380
# state saved, iteration 122390
# state saved, iteration 122400
# state saved, iteration 122410
# state saved, iteration 122420
# state saved, iteration 122430
# state saved, iteration 122440
# state saved, iteration 122450
# state saved, iteration 122460
# state saved, iteration 122470
# state saved, iteration 122480
# state saved, iteration 122490
# state saved, iteration 122500
# state saved, iteration 122510
# state saved, iteration 122520
# state saved, iteration 122530
# state saved, iteration 122540
# state saved, iteration 122550
# state saved, iteration 122560
# state saved, iteration 122570
# state saved, iteration 122580
# state saved, iteration 122590
# state saved, iteration 122600
# state saved, iteration 122610
# state saved, iteration 122620
# state saved, iteration 122630
# state saved, iteration 122640
# state saved, iteration 122650
# state saved, iteration 122660
# state saved, iteration 122670
# state saved, iteration 122680
# state saved, iteration 122690
# state saved, iteration 122700
# state saved, iteration 122710
# state saved, iteration 122720
# state saved, iteration 122730
# state saved, iteration 122740
# state saved, iteration 122750
# state saved, iteration 122760
# state saved, iteration 122770
# state saved, iteration 122780
# state saved, iteration 122790
# state saved, iteration 122800
# state saved, iteration 122810
# state saved, iteration 122820
# state saved, iteration 122830
# state saved, iteration 122840
# state saved, iteration 122850
# state saved, iteration 122860
# state saved, iteration 122870
# state saved, iteration 122880
# state saved, iteration 122890
# state saved, iteration 122900
# state saved, iteration 122910
# state saved, iteration 122920
# state saved, iteration 122930
# state saved, iteration 122940
# state saved, iteration 122950
# state saved, iteration 122960
# state saved, iteration 122970
# state saved, iteration 122980
# state saved, iteration 122990
# state saved, iteration 123000
# state saved, iteration 123010
# state saved, iteration 123020
# state saved, iteration 123030
# state saved, iteration 123040
# state saved, iteration 123050
# state saved, iteration 123060
# state saved, iteration 123070
# state saved, iteration 123080
# state saved, iteration 123090
# state saved, iteration 123100
# state saved, iteration 123110
# state saved, iteration 123120
# state saved, iteration 123130
# state saved, iteration 123140
# state saved, iteration 123150
# state saved, iteration 123160
# state saved, iteration 123170
# state saved, iteration 123180
# state saved, iteration 123190
# state saved, iteration 123200
# state saved, iteration 123210
# state saved, iteration 123220
# state saved, iteration 123230
# state saved, iteration 123240
# state saved, iteration 123250
# state saved, iteration 123260
# state saved, iteration 123270
# state saved, iteration 123280
# state saved, iteration 123290
# state saved, iteration 123300
# state saved, iteration 123310
# state saved, iteration 123320
# state saved, iteration 123330
# state saved, iteration 123340
# state saved, iteration 123350
# state saved, iteration 123360
# state saved, iteration 123370
# state saved, iteration 123380
# state saved, iteration 123390
# state saved, iteration 123400
# state saved, iteration 123410
# state saved, iteration 123420
# state saved, iteration 123430
# state saved, iteration 123440
# state saved, iteration 123450
# state saved, iteration 123460
# state saved, iteration 123470
# state saved, iteration 123480
# state saved, iteration 123490
# state saved, iteration 123500
# state saved, iteration 123510
# state saved, iteration 123520
# state saved, iteration 123530
# state saved, iteration 123540
# state saved, iteration 123550
# state saved, iteration 123560
# state saved, iteration 123570
# state saved, iteration 123580
# state saved, iteration 123590
# state saved, iteration 123600
# state saved, iteration 123610
# state saved, iteration 123620
# state saved, iteration 123630
# state saved, iteration 123640
# state saved, iteration 123650
# state saved, iteration 123660
# state saved, iteration 123670
# state saved, iteration 123680
# state saved, iteration 123690
# state saved, iteration 123700
# state saved, iteration 123710
# state saved, iteration 123720
# state saved, iteration 123730
# state saved, iteration 123740
# state saved, iteration 123750
# state saved, iteration 123760
# state saved, iteration 123770
# state saved, iteration 123780
# state saved, iteration 123790
# state saved, iteration 123800
# state saved, iteration 123810
# state saved, iteration 123820
# state saved, iteration 123830
# state saved, iteration 123840
# state saved, iteration 123850
# state saved, iteration 123860
# state saved, iteration 123870
# state saved, iteration 123880
# state saved, iteration 123890
# state saved, iteration 123900
# state saved, iteration 123910
# state saved, iteration 123920
# state saved, iteration 123930
# state saved, iteration 123940
# state saved, iteration 123950
# state saved, iteration 123960
# state saved, iteration 123970
# state saved, iteration 123980
# state saved, iteration 123990
# state saved, iteration 124000
# state saved, iteration 124010
# state saved, iteration 124020
# state saved, iteration 124030
# state saved, iteration 124040
# state saved, iteration 124050
# state saved, iteration 124060
# state saved, iteration 124070
# state saved, iteration 124080
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# state saved, iteration 124090
# state saved, iteration 124100
# state saved, iteration 124110
# state saved, iteration 124120
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# state saved, iteration 124130
# state saved, iteration 124140
# state saved, iteration 124150
# state saved, iteration 124160
# state saved, iteration 124170
# state saved, iteration 124180
# state saved, iteration 124190
# state saved, iteration 124200
# state saved, iteration 124210
# state saved, iteration 124220
# state saved, iteration 124230
# state saved, iteration 124240
# state saved, iteration 124250
# state saved, iteration 124260
# state saved, iteration 124270
# state saved, iteration 124280
# state saved, iteration 124290
# state saved, iteration 124300
# state saved, iteration 124310
# state saved, iteration 124320
# state saved, iteration 124330
# state saved, iteration 124340
# state saved, iteration 124350
# state saved, iteration 124360
# state saved, iteration 124370
# state saved, iteration 124380
# state saved, iteration 124390
# state saved, iteration 124400
# state saved, iteration 124410
# state saved, iteration 124420
# state saved, iteration 124430
# state saved, iteration 124440
# state saved, iteration 124450
# state saved, iteration 124460
# state saved, iteration 124470
# state saved, iteration 124480
# state saved, iteration 124490
# state saved, iteration 124500
# state saved, iteration 124510
# state saved, iteration 124520
# state saved, iteration 124530
# state saved, iteration 124540
# state saved, iteration 124550
# state saved, iteration 124560
# state saved, iteration 124570
# state saved, iteration 124580
# state saved, iteration 124590
# state saved, iteration 124600
# state saved, iteration 124610
# state saved, iteration 124620
# state saved, iteration 124630
# state saved, iteration 124640
# state saved, iteration 124650
# state saved, iteration 124660
# state saved, iteration 124670
# state saved, iteration 124680
# state saved, iteration 124690
# state saved, iteration 124700
# state saved, iteration 124710
# state saved, iteration 124720
# state saved, iteration 124730
# state saved, iteration 124740
# state saved, iteration 124750
# state saved, iteration 124760
# state saved, iteration 124770
# state saved, iteration 124780
# state saved, iteration 124790
# state saved, iteration 124800
# state saved, iteration 124810
# state saved, iteration 124820
# state saved, iteration 124830
# state saved, iteration 124840
# state saved, iteration 124850
# state saved, iteration 124860
# state saved, iteration 124870
# state saved, iteration 124880
# state saved, iteration 124890
# state saved, iteration 124900
# state saved, iteration 124910
# state saved, iteration 124920
# state saved, iteration 124930
# state saved, iteration 124940
# state saved, iteration 124950
# state saved, iteration 124960
# state saved, iteration 124970
# state saved, iteration 124980
# state saved, iteration 124990
# state saved, iteration 125000
# state saved, iteration 125010
# state saved, iteration 125020
# state saved, iteration 125030
# state saved, iteration 125040
# state saved, iteration 125050
# state saved, iteration 125060
# state saved, iteration 125070
# state saved, iteration 125080
# state saved, iteration 125090
# state saved, iteration 125100
# state saved, iteration 125110
# state saved, iteration 125120
# state saved, iteration 125130
# state saved, iteration 125140
# state saved, iteration 125150
# state saved, iteration 125160
# state saved, iteration 125170
# state saved, iteration 125180
# state saved, iteration 125190
# state saved, iteration 125200
# state saved, iteration 125210
# state saved, iteration 125220
# state saved, iteration 125230
# state saved, iteration 125240
# state saved, iteration 125250
# state saved, iteration 125260
# state saved, iteration 125270
# state saved, iteration 125280
# state saved, iteration 125290
# state saved, iteration 125300
# state saved, iteration 125310
# state saved, iteration 125320
# state saved, iteration 125330
# state saved, iteration 125340
# state saved, iteration 125350
# state saved, iteration 125360
# state saved, iteration 125370
# state saved, iteration 125380
# state saved, iteration 125390
# state saved, iteration 125400
# state saved, iteration 125410
# state saved, iteration 125420
# state saved, iteration 125430
# state saved, iteration 125440
# state saved, iteration 125450
# state saved, iteration 125460
# state saved, iteration 125470
# state saved, iteration 125480
# state saved, iteration 125490
# state saved, iteration 125500
# state saved, iteration 125510
# state saved, iteration 125520
# state saved, iteration 125530
# state saved, iteration 125540
# state saved, iteration 125550
# state saved, iteration 125560
# state saved, iteration 125570
# state saved, iteration 125580
# state saved, iteration 125590
# state saved, iteration 125600
# state saved, iteration 125610
# state saved, iteration 125620
# state saved, iteration 125630
# state saved, iteration 125640
# state saved, iteration 125650
# state saved, iteration 125660
# state saved, iteration 125670
# state saved, iteration 125680
# state saved, iteration 125690
# state saved, iteration 125700
# state saved, iteration 125710
# state saved, iteration 125720
# state saved, iteration 125730
# state saved, iteration 125740
# state saved, iteration 125750
# state saved, iteration 125760
# state saved, iteration 125770
# state saved, iteration 125780
# state saved, iteration 125790
# state saved, iteration 125800
# state saved, iteration 125810
# state saved, iteration 125820
# state saved, iteration 125830
# state saved, iteration 125840
# state saved, iteration 125850
# state saved, iteration 125860
# state saved, iteration 125870
# state saved, iteration 125880
# state saved, iteration 125890
# state saved, iteration 125900
# state saved, iteration 125910
# state saved, iteration 125920
# state saved, iteration 125930
# state saved, iteration 125940
# state saved, iteration 125950
# state saved, iteration 125960
# state saved, iteration 125970
# state saved, iteration 125980
# state saved, iteration 125990
# state saved, iteration 126000
# state saved, iteration 126010
# state saved, iteration 126020
# state saved, iteration 126030
# state saved, iteration 126040
# state saved, iteration 126050
# state saved, iteration 126060
# state saved, iteration 126070
# state saved, iteration 126080
# state saved, iteration 126090
# state saved, iteration 126100
# state saved, iteration 126110
# state saved, iteration 126120
# state saved, iteration 126130
# state saved, iteration 126140
# state saved, iteration 126150
# state saved, iteration 126160
# state saved, iteration 126170
# state saved, iteration 126180
# state saved, iteration 126190
# state saved, iteration 126200
# state saved, iteration 126210
# state saved, iteration 126220
# state saved, iteration 126230
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# state saved, iteration 126240
# state saved, iteration 126250
# state saved, iteration 126260
# state saved, iteration 126270
# state saved, iteration 126280
# state saved, iteration 126290
# state saved, iteration 126300
# state saved, iteration 126310
# state saved, iteration 126320
# state saved, iteration 126330
# state saved, iteration 126340
# state saved, iteration 126350
# state saved, iteration 126360
# state saved, iteration 126370
# state saved, iteration 126380
# state saved, iteration 126390
# state saved, iteration 126400
# state saved, iteration 126410
# state saved, iteration 126420
# state saved, iteration 126430
# state saved, iteration 126440
# state saved, iteration 126450
# state saved, iteration 126460
# state saved, iteration 126470
# state saved, iteration 126480
# state saved, iteration 126490
# state saved, iteration 126500
# state saved, iteration 126510
# state saved, iteration 126520
# state saved, iteration 126530
# state saved, iteration 126540
# state saved, iteration 126550
# state saved, iteration 126560
# state saved, iteration 126570
# state saved, iteration 126580
# state saved, iteration 126590
# state saved, iteration 126600
# state saved, iteration 126610
# state saved, iteration 126620
# state saved, iteration 126630
# state saved, iteration 126640
# state saved, iteration 126650
# state saved, iteration 126660
# state saved, iteration 126670
# state saved, iteration 126680
# state saved, iteration 126690
# state saved, iteration 126700
# state saved, iteration 126710
# state saved, iteration 126720
# state saved, iteration 126730
# state saved, iteration 126740
# state saved, iteration 126750
# state saved, iteration 126760
# state saved, iteration 126770
# state saved, iteration 126780
# state saved, iteration 126790
# state saved, iteration 126800
# state saved, iteration 126810
# state saved, iteration 126820
# state saved, iteration 126830
# state saved, iteration 126840
# state saved, iteration 126850
# state saved, iteration 126860
# state saved, iteration 126870
# state saved, iteration 126880
# state saved, iteration 126890
# state saved, iteration 126900
# state saved, iteration 126910
# state saved, iteration 126920
# state saved, iteration 126930
# state saved, iteration 126940
# state saved, iteration 126950
# state saved, iteration 126960
# state saved, iteration 126970
# state saved, iteration 126980
# state saved, iteration 126990
# state saved, iteration 127000
# state saved, iteration 127010
# state saved, iteration 127020
# state saved, iteration 127030
# state saved, iteration 127040
# state saved, iteration 127050
# state saved, iteration 127060
# state saved, iteration 127070
# state saved, iteration 127080
# state saved, iteration 127090
# state saved, iteration 127100
# state saved, iteration 127110
# state saved, iteration 127120
# state saved, iteration 127130
# state saved, iteration 127140
# state saved, iteration 127150
# state saved, iteration 127160
# state saved, iteration 127170
# state saved, iteration 127180
# state saved, iteration 127190
# state saved, iteration 127200
# state saved, iteration 127210
# state saved, iteration 127220
# state saved, iteration 127230
# state saved, iteration 127240
# state saved, iteration 127250
# state saved, iteration 127260
# state saved, iteration 127270
# state saved, iteration 127280
# state saved, iteration 127290
# state saved, iteration 127300
# state saved, iteration 127310
# state saved, iteration 127320
# state saved, iteration 127330
# state saved, iteration 127340
# state saved, iteration 127350
# state saved, iteration 127360
# state saved, iteration 127370
# state saved, iteration 127380
# state saved, iteration 127390
# state saved, iteration 127400
# state saved, iteration 127410
# state saved, iteration 127420
# state saved, iteration 127430
# state saved, iteration 127440
# state saved, iteration 127450
# state saved, iteration 127460
# state saved, iteration 127470
# state saved, iteration 127480
# state saved, iteration 127490
# state saved, iteration 127500
# state saved, iteration 127510
# state saved, iteration 127520
# state saved, iteration 127530
# state saved, iteration 127540
# state saved, iteration 127550
# state saved, iteration 127560
# state saved, iteration 127570
# state saved, iteration 127580
# state saved, iteration 127590
# state saved, iteration 127600
# state saved, iteration 127610
# state saved, iteration 127620
# state saved, iteration 127630
# state saved, iteration 127640
# state saved, iteration 127650
# state saved, iteration 127660
# state saved, iteration 127670
# state saved, iteration 127680
# state saved, iteration 127690
# state saved, iteration 127700
# state saved, iteration 127710
# state saved, iteration 127720
# state saved, iteration 127730
# state saved, iteration 127740
# state saved, iteration 127750
# state saved, iteration 127760
# state saved, iteration 127770
# state saved, iteration 127780
# state saved, iteration 127790
# state saved, iteration 127800
# state saved, iteration 127810
# state saved, iteration 127820
# state saved, iteration 127830
# state saved, iteration 127840
# state saved, iteration 127850
# state saved, iteration 127860
# state saved, iteration 127870
# state saved, iteration 127880
# state saved, iteration 127890
# state saved, iteration 127900
# state saved, iteration 127910
# state saved, iteration 127920
# state saved, iteration 127930
# state saved, iteration 127940
# state saved, iteration 127950
# state saved, iteration 127960
# state saved, iteration 127970
# state saved, iteration 127980
# state saved, iteration 127990
# state saved, iteration 128000
# state saved, iteration 128010
# state saved, iteration 128020
# state saved, iteration 128030
# state saved, iteration 128040
# state saved, iteration 128050
# state saved, iteration 128060
# state saved, iteration 128070
# state saved, iteration 128080
# state saved, iteration 128090
# state saved, iteration 128100
# state saved, iteration 128110
# state saved, iteration 128120
# state saved, iteration 128130
# state saved, iteration 128140
# state saved, iteration 128150
# state saved, iteration 128160
# state saved, iteration 128170
# state saved, iteration 128180
# state saved, iteration 128190
# state saved, iteration 128200
# state saved, iteration 128210
# state saved, iteration 128220
# state saved, iteration 128230
# state saved, iteration 128240
# state saved, iteration 128250
# state saved, iteration 128260
# state saved, iteration 128270
# state saved, iteration 128280
# state saved, iteration 128290
# state saved, iteration 128300
# state saved, iteration 128310
# state saved, iteration 128320
# state saved, iteration 128330
# state saved, iteration 128340
# state saved, iteration 128350
# state saved, iteration 128360
# state saved, iteration 128370
# state saved, iteration 128380
# state saved, iteration 128390
# state saved, iteration 128400
# state saved, iteration 128410
# state saved, iteration 128420
# state saved, iteration 128430
# state saved, iteration 128440
# state saved, iteration 128450
# state saved, iteration 128460
# state saved, iteration 128470
# state saved, iteration 128480
# state saved, iteration 128490
# state saved, iteration 128500
# state saved, iteration 128510
# state saved, iteration 128520
# state saved, iteration 128530
# state saved, iteration 128540
# state saved, iteration 128550
# state saved, iteration 128560
# state saved, iteration 128570
# state saved, iteration 128580
# state saved, iteration 128590
# state saved, iteration 128600
# state saved, iteration 128610
# state saved, iteration 128620
# state saved, iteration 128630
# state saved, iteration 128640
# state saved, iteration 128650
# state saved, iteration 128660
# state saved, iteration 128670
# state saved, iteration 128680
# state saved, iteration 128690
# state saved, iteration 128700
# state saved, iteration 128710
# state saved, iteration 128720
# state saved, iteration 128730
# state saved, iteration 128740
# state saved, iteration 128750
# state saved, iteration 128760
# state saved, iteration 128770
# state saved, iteration 128780
# state saved, iteration 128790
# state saved, iteration 128800
# state saved, iteration 128810
# state saved, iteration 128820
# state saved, iteration 128830
# state saved, iteration 128840
# state saved, iteration 128850
# state saved, iteration 128860
# state saved, iteration 128870
# state saved, iteration 128880
# state saved, iteration 128890
# state saved, iteration 128900
# state saved, iteration 128910
# state saved, iteration 128920
# state saved, iteration 128930
# state saved, iteration 128940
# state saved, iteration 128950
# state saved, iteration 128960
# state saved, iteration 128970
# state saved, iteration 128980
# state saved, iteration 128990
# state saved, iteration 129000
# state saved, iteration 129010
# state saved, iteration 129020
# state saved, iteration 129030
# state saved, iteration 129040
# state saved, iteration 129050
# state saved, iteration 129060
# state saved, iteration 129070
# state saved, iteration 129080
# state saved, iteration 129090
# state saved, iteration 129100
# state saved, iteration 129110
# state saved, iteration 129120
# state saved, iteration 129130
# state saved, iteration 129140
# state saved, iteration 129150
# state saved, iteration 129160
# state saved, iteration 129170
# state saved, iteration 129180
# state saved, iteration 129190
# state saved, iteration 129200
# state saved, iteration 129210
# state saved, iteration 129220
# state saved, iteration 129230
# state saved, iteration 129240
# HTTP Error 404: Not Found
# state saved, iteration 129250
# HTTP Error 404: Not Found
# state saved, iteration 129260
# state saved, iteration 129270
# state saved, iteration 129280
# state saved, iteration 129290
# state saved, iteration 129300
# state saved, iteration 129310
# state saved, iteration 129320
# state saved, iteration 129330
# state saved, iteration 129340
# state saved, iteration 129350
# state saved, iteration 129360
# state saved, iteration 129370
# state saved, iteration 129380
# state saved, iteration 129390
# state saved, iteration 129400
# state saved, iteration 129410
# state saved, iteration 129420
# state saved, iteration 129430
# state saved, iteration 129440
# state saved, iteration 129450
# state saved, iteration 129460
# state saved, iteration 129470
# state saved, iteration 129480
# state saved, iteration 129490
# state saved, iteration 129500
# state saved, iteration 129510
# state saved, iteration 129520
# state saved, iteration 129530
# state saved, iteration 129540
# state saved, iteration 129550
# state saved, iteration 129560
# HTTP Error 404: Not Found
# state saved, iteration 129570
# HTTP Error 404: Not Found
# state saved, iteration 129580
# state saved, iteration 129590
# state saved, iteration 129600
# state saved, iteration 129610
# state saved, iteration 129620
# state saved, iteration 129630
# state saved, iteration 129640
# state saved, iteration 129650
# state saved, iteration 129660
# state saved, iteration 129670
# state saved, iteration 129680
# state saved, iteration 129690
# state saved, iteration 129700
# state saved, iteration 129710
# state saved, iteration 129720
# state saved, iteration 129730
# state saved, iteration 129740
# state saved, iteration 129750
# state saved, iteration 129760
# state saved, iteration 129770
# state saved, iteration 129780
# state saved, iteration 129790
# state saved, iteration 129800
# state saved, iteration 129810
# state saved, iteration 129820
# state saved, iteration 129830
# state saved, iteration 129840
# state saved, iteration 129850
# state saved, iteration 129860
# state saved, iteration 129870
# state saved, iteration 129880
# state saved, iteration 129890
# state saved, iteration 129900
# state saved, iteration 129910
# state saved, iteration 129920
# state saved, iteration 129930
# state saved, iteration 129940
# state saved, iteration 129950
# state saved, iteration 129960
# state saved, iteration 129970
# state saved, iteration 129980
# state saved, iteration 129990
# state saved, iteration 130000
# state saved, iteration 130010
# state saved, iteration 130020
# state saved, iteration 130030
# state saved, iteration 130040
# state saved, iteration 130050
# state saved, iteration 130060
# state saved, iteration 130070
# state saved, iteration 130080
# state saved, iteration 130090
# state saved, iteration 130100
# state saved, iteration 130110
# state saved, iteration 130120
# state saved, iteration 130130
# state saved, iteration 130140
# state saved, iteration 130150
# state saved, iteration 130160
# state saved, iteration 130170
# state saved, iteration 130180
# state saved, iteration 130190
# state saved, iteration 130200
# state saved, iteration 130210
# state saved, iteration 130220
# state saved, iteration 130230
# state saved, iteration 130240
# state saved, iteration 130250
# state saved, iteration 130260
# state saved, iteration 130270
# state saved, iteration 130280
# state saved, iteration 130290
# state saved, iteration 130300
# state saved, iteration 130310
# state saved, iteration 130320
# state saved, iteration 130330
# state saved, iteration 130340
# state saved, iteration 130350
# state saved, iteration 130360
# state saved, iteration 130370
# state saved, iteration 130380
# state saved, iteration 130390
# state saved, iteration 130400
# state saved, iteration 130410
# state saved, iteration 130420
# state saved, iteration 130430
# state saved, iteration 130440
# state saved, iteration 130450
# state saved, iteration 130460
# state saved, iteration 130470
# state saved, iteration 130480
# state saved, iteration 130490
# state saved, iteration 130500
# state saved, iteration 130510
# state saved, iteration 130520
# state saved, iteration 130530
# state saved, iteration 130540
# state saved, iteration 130550
# state saved, iteration 130560
# state saved, iteration 130570
# state saved, iteration 130580
# state saved, iteration 130590
# state saved, iteration 130600
# state saved, iteration 130610
# state saved, iteration 130620
# state saved, iteration 130630
# state saved, iteration 130640
# state saved, iteration 130650
# state saved, iteration 130660
# state saved, iteration 130670
# state saved, iteration 130680
# state saved, iteration 130690
# state saved, iteration 130700
# state saved, iteration 130710
# state saved, iteration 130720
# state saved, iteration 130730
# state saved, iteration 130740
# state saved, iteration 130750
# state saved, iteration 130760
# state saved, iteration 130770
# state saved, iteration 130780
# state saved, iteration 130790
# state saved, iteration 130800
# state saved, iteration 130810
# state saved, iteration 130820
# state saved, iteration 130830
# state saved, iteration 130840
# state saved, iteration 130850
# state saved, iteration 130860
# state saved, iteration 130870
# state saved, iteration 130880
# state saved, iteration 130890
# state saved, iteration 130900
# state saved, iteration 130910
# state saved, iteration 130920
# state saved, iteration 130930
# state saved, iteration 130940
# state saved, iteration 130950
# state saved, iteration 130960
# state saved, iteration 130970
# state saved, iteration 130980
# state saved, iteration 130990
# state saved, iteration 131000
# state saved, iteration 131010
# state saved, iteration 131020
# state saved, iteration 131030
# state saved, iteration 131040
# state saved, iteration 131050
# state saved, iteration 131060
# state saved, iteration 131070
# state saved, iteration 131080
# state saved, iteration 131090
# state saved, iteration 131100
# state saved, iteration 131110
# state saved, iteration 131120
# state saved, iteration 131130
# state saved, iteration 131140
# state saved, iteration 131150
# state saved, iteration 131160
# state saved, iteration 131170
# state saved, iteration 131180
# state saved, iteration 131190
# state saved, iteration 131200
# state saved, iteration 131210
# state saved, iteration 131220
# state saved, iteration 131230
# state saved, iteration 131240
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# state saved, iteration 131250
# state saved, iteration 131260
# state saved, iteration 131270
# state saved, iteration 131280
# state saved, iteration 131290
# state saved, iteration 131300
# state saved, iteration 131310
# state saved, iteration 131320
# state saved, iteration 131330
# state saved, iteration 131340
# state saved, iteration 131350
# state saved, iteration 131360
# state saved, iteration 131370
# state saved, iteration 131380
# state saved, iteration 131390
# state saved, iteration 131400
# state saved, iteration 131410
# state saved, iteration 131420
# state saved, iteration 131430
# state saved, iteration 131440
# state saved, iteration 131450
# state saved, iteration 131460
# state saved, iteration 131470
# state saved, iteration 131480
# state saved, iteration 131490
# state saved, iteration 131500
# state saved, iteration 131510
# state saved, iteration 131520
# state saved, iteration 131530
# state saved, iteration 131540
# state saved, iteration 131550
# state saved, iteration 131560
# state saved, iteration 131570
# state saved, iteration 131580
# state saved, iteration 131590
# state saved, iteration 131600
# state saved, iteration 131610
# state saved, iteration 131620
# state saved, iteration 131630
# state saved, iteration 131640
# state saved, iteration 131650
# state saved, iteration 131660
# state saved, iteration 131670
# state saved, iteration 131680
# state saved, iteration 131690
# state saved, iteration 131700
# state saved, iteration 131710
# state saved, iteration 131720
# state saved, iteration 131730
# state saved, iteration 131740
# state saved, iteration 131750
# state saved, iteration 131760
# state saved, iteration 131770
# state saved, iteration 131780
# state saved, iteration 131790
# state saved, iteration 131800
# state saved, iteration 131810
# state saved, iteration 131820
# state saved, iteration 131830
# state saved, iteration 131840
# state saved, iteration 131850
# state saved, iteration 131860
# state saved, iteration 131870
# state saved, iteration 131880
# state saved, iteration 131890
# state saved, iteration 131900
# state saved, iteration 131910
# state saved, iteration 131920
# state saved, iteration 131930
# state saved, iteration 131940
# state saved, iteration 131950
# state saved, iteration 131960
# state saved, iteration 131970
# state saved, iteration 131980
# state saved, iteration 131990
# state saved, iteration 132000
# state saved, iteration 132010
# state saved, iteration 132020
# state saved, iteration 132030
# state saved, iteration 132040
# state saved, iteration 132050
# state saved, iteration 132060
# state saved, iteration 132070
# state saved, iteration 132080
# state saved, iteration 132090
# state saved, iteration 132100
# state saved, iteration 132110
# state saved, iteration 132120
# state saved, iteration 132130
# state saved, iteration 132140
# state saved, iteration 132150
# state saved, iteration 132160
# state saved, iteration 132170
# state saved, iteration 132180
# state saved, iteration 132190
# state saved, iteration 132200
# state saved, iteration 132210
# state saved, iteration 132220
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# state saved, iteration 132230
# state saved, iteration 132240
# state saved, iteration 132250
# state saved, iteration 132260
# state saved, iteration 132270
# state saved, iteration 132280
# state saved, iteration 132290
# state saved, iteration 132300
# state saved, iteration 132310
# state saved, iteration 132320
# state saved, iteration 132330
# state saved, iteration 132340
# state saved, iteration 132350
# state saved, iteration 132360
# state saved, iteration 132370
# state saved, iteration 132380
# state saved, iteration 132390
# state saved, iteration 132400
# state saved, iteration 132410
# state saved, iteration 132420
# state saved, iteration 132430
# state saved, iteration 132440
# state saved, iteration 132450
# state saved, iteration 132460
# state saved, iteration 132470
# state saved, iteration 132480
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# state saved, iteration 132490
# state saved, iteration 132500
# state saved, iteration 132510
# state saved, iteration 132520
# state saved, iteration 132530
# state saved, iteration 132540
# state saved, iteration 132550
# state saved, iteration 132560
# state saved, iteration 132570
# state saved, iteration 132580
# state saved, iteration 132590
# state saved, iteration 132600
# state saved, iteration 132610
# state saved, iteration 132620
# state saved, iteration 132630
# state saved, iteration 132640
# state saved, iteration 132650
# state saved, iteration 132660
# state saved, iteration 132670
# state saved, iteration 132680
# state saved, iteration 132690
# state saved, iteration 132700
# state saved, iteration 132710
# state saved, iteration 132720
# state saved, iteration 132730
# state saved, iteration 132740
# state saved, iteration 132750
# state saved, iteration 132760
# state saved, iteration 132770
# state saved, iteration 132780
# state saved, iteration 132790
# state saved, iteration 132800
# state saved, iteration 132810
# state saved, iteration 132820
# state saved, iteration 132830
# state saved, iteration 132840
# state saved, iteration 132850
# state saved, iteration 132860
# state saved, iteration 132870
# state saved, iteration 132880
# state saved, iteration 132890
# state saved, iteration 132900
# state saved, iteration 132910
# state saved, iteration 132920
# state saved, iteration 132930
# state saved, iteration 132940
# state saved, iteration 132950
# state saved, iteration 132960
# state saved, iteration 132970
# state saved, iteration 132980
# state saved, iteration 132990
# state saved, iteration 133000
# state saved, iteration 133010
# state saved, iteration 133020
# state saved, iteration 133030
# state saved, iteration 133040
# state saved, iteration 133050
# state saved, iteration 133060
# state saved, iteration 133070
# state saved, iteration 133080
# state saved, iteration 133090
# state saved, iteration 133100
# state saved, iteration 133110
# state saved, iteration 133120
# state saved, iteration 133130
# state saved, iteration 133140
# state saved, iteration 133150
# state saved, iteration 133160
# state saved, iteration 133170
# state saved, iteration 133180
# state saved, iteration 133190
# state saved, iteration 133200
# state saved, iteration 133210
# state saved, iteration 133220
# state saved, iteration 133230
# state saved, iteration 133240
# state saved, iteration 133250
# state saved, iteration 133260
# state saved, iteration 133270
# state saved, iteration 133280
# state saved, iteration 133290
# state saved, iteration 133300
# state saved, iteration 133310
# state saved, iteration 133320
# state saved, iteration 133330
# state saved, iteration 133340
# state saved, iteration 133350
# state saved, iteration 133360
# state saved, iteration 133370
# state saved, iteration 133380
# state saved, iteration 133390
# state saved, iteration 133400
# state saved, iteration 133410
# state saved, iteration 133420
# state saved, iteration 133430
# state saved, iteration 133440
# state saved, iteration 133450
# state saved, iteration 133460
# state saved, iteration 133470
# state saved, iteration 133480
# state saved, iteration 133490
# state saved, iteration 133500
# state saved, iteration 133510
# state saved, iteration 133520
# state saved, iteration 133530
# state saved, iteration 133540
# state saved, iteration 133550
# state saved, iteration 133560
# state saved, iteration 133570
# state saved, iteration 133580
# state saved, iteration 133590
# state saved, iteration 133600
# state saved, iteration 133610
# state saved, iteration 133620
# state saved, iteration 133630
# state saved, iteration 133640
# state saved, iteration 133650
# state saved, iteration 133660
# state saved, iteration 133670
# state saved, iteration 133680
# state saved, iteration 133690
# state saved, iteration 133700
# state saved, iteration 133710
# state saved, iteration 133720
# state saved, iteration 133730
# state saved, iteration 133740
# state saved, iteration 133750
# state saved, iteration 133760
# state saved, iteration 133770
# state saved, iteration 133780
# state saved, iteration 133790
# state saved, iteration 133800
# state saved, iteration 133810
# state saved, iteration 133820
# state saved, iteration 133830
# state saved, iteration 133840
# state saved, iteration 133850
# state saved, iteration 133860
# state saved, iteration 133870
# state saved, iteration 133880
# state saved, iteration 133890
# state saved, iteration 133900
# state saved, iteration 133910
# state saved, iteration 133920
# state saved, iteration 133930
# state saved, iteration 133940
# state saved, iteration 133950
# state saved, iteration 133960
# state saved, iteration 133970
# state saved, iteration 133980
# state saved, iteration 133990
# state saved, iteration 134000
# state saved, iteration 134010
# state saved, iteration 134020
# state saved, iteration 134030
# state saved, iteration 134040
# state saved, iteration 134050
# state saved, iteration 134060
# state saved, iteration 134070
# state saved, iteration 134080
# state saved, iteration 134090
# state saved, iteration 134100
# state saved, iteration 134110
# state saved, iteration 134120
# state saved, iteration 134130
# state saved, iteration 134140
# state saved, iteration 134150
# state saved, iteration 134160
# state saved, iteration 134170
# state saved, iteration 134180
# state saved, iteration 134190
# state saved, iteration 134200
# state saved, iteration 134210
# state saved, iteration 134220
# state saved, iteration 134230
# state saved, iteration 134240
# state saved, iteration 134250
# state saved, iteration 134260
# state saved, iteration 134270
# state saved, iteration 134280
# state saved, iteration 134290
# state saved, iteration 134300
# state saved, iteration 134310
# state saved, iteration 134320
# state saved, iteration 134330
# state saved, iteration 134340
# state saved, iteration 134350
# state saved, iteration 134360
# state saved, iteration 134370
# state saved, iteration 134380
# state saved, iteration 134390
# state saved, iteration 134400
# state saved, iteration 134410
# state saved, iteration 134420
# state saved, iteration 134430
# state saved, iteration 134440
# state saved, iteration 134450
# state saved, iteration 134460
# state saved, iteration 134470
# state saved, iteration 134480
# state saved, iteration 134490
# state saved, iteration 134500
# state saved, iteration 134510
# state saved, iteration 134520
# state saved, iteration 134530
# state saved, iteration 134540
# state saved, iteration 134550
# state saved, iteration 134560
# state saved, iteration 134570
# state saved, iteration 134580
# state saved, iteration 134590
# state saved, iteration 134600
# state saved, iteration 134610
# state saved, iteration 134620
# state saved, iteration 134630
# state saved, iteration 134640
# state saved, iteration 134650
# state saved, iteration 134660
# state saved, iteration 134670
# state saved, iteration 134680
# state saved, iteration 134690
# state saved, iteration 134700
# state saved, iteration 134710
# state saved, iteration 134720
# state saved, iteration 134730
# state saved, iteration 134740
# state saved, iteration 134750
# state saved, iteration 134760
# state saved, iteration 134770
# state saved, iteration 134780
# state saved, iteration 134790
# state saved, iteration 134800
# state saved, iteration 134810
# state saved, iteration 134820
# state saved, iteration 134830
# state saved, iteration 134840
# state saved, iteration 134850
# state saved, iteration 134860
# state saved, iteration 134870
# state saved, iteration 134880
# state saved, iteration 134890
# state saved, iteration 134900
# state saved, iteration 134910
# state saved, iteration 134920
# state saved, iteration 134930
# state saved, iteration 134940
# state saved, iteration 134950
# state saved, iteration 134960
# state saved, iteration 134970
# state saved, iteration 134980
# state saved, iteration 134990
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# state saved, iteration 135000
# state saved, iteration 135010
# state saved, iteration 135020
# state saved, iteration 135030
# state saved, iteration 135040
# state saved, iteration 135050
# state saved, iteration 135060
# state saved, iteration 135070
# state saved, iteration 135080
# state saved, iteration 135090
# state saved, iteration 135100
# state saved, iteration 135110
# state saved, iteration 135120
# state saved, iteration 135130
# state saved, iteration 135140
# state saved, iteration 135150
# state saved, iteration 135160
# state saved, iteration 135170
# state saved, iteration 135180
# state saved, iteration 135190
# state saved, iteration 135200
# state saved, iteration 135210
# state saved, iteration 135220
# state saved, iteration 135230
# state saved, iteration 135240
# state saved, iteration 135250
# state saved, iteration 135260
# state saved, iteration 135270
# state saved, iteration 135280
# state saved, iteration 135290
# state saved, iteration 135300
# state saved, iteration 135310
# state saved, iteration 135320
# state saved, iteration 135330
# state saved, iteration 135340
# state saved, iteration 135350
# state saved, iteration 135360
# state saved, iteration 135370
# state saved, iteration 135380
# state saved, iteration 135390
# state saved, iteration 135400
# state saved, iteration 135410
# state saved, iteration 135420
# state saved, iteration 135430
# state saved, iteration 135440
# state saved, iteration 135450
# state saved, iteration 135460
# state saved, iteration 135470
# state saved, iteration 135480
# state saved, iteration 135490
# state saved, iteration 135500
# state saved, iteration 135510
# state saved, iteration 135520
# state saved, iteration 135530
# state saved, iteration 135540
# state saved, iteration 135550
# state saved, iteration 135560
# state saved, iteration 135570
# state saved, iteration 135580
# state saved, iteration 135590
# state saved, iteration 135600
# state saved, iteration 135610
# state saved, iteration 135620
# state saved, iteration 135630
# state saved, iteration 135640
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# state saved, iteration 135650
# state saved, iteration 135660
# state saved, iteration 135670
# state saved, iteration 135680
# state saved, iteration 135690
# state saved, iteration 135700
# state saved, iteration 135710
# state saved, iteration 135720
# state saved, iteration 135730
# state saved, iteration 135740
# state saved, iteration 135750
# state saved, iteration 135760
# state saved, iteration 135770
# state saved, iteration 135780
# state saved, iteration 135790
# state saved, iteration 135800
# state saved, iteration 135810
# state saved, iteration 135820
# state saved, iteration 135830
# state saved, iteration 135840
# state saved, iteration 135850
# state saved, iteration 135860
# state saved, iteration 135870
# state saved, iteration 135880
# state saved, iteration 135890
# state saved, iteration 135900
# state saved, iteration 135910
# state saved, iteration 135920
# state saved, iteration 135930
# state saved, iteration 135940
# state saved, iteration 135950
# state saved, iteration 135960
# state saved, iteration 135970
# state saved, iteration 135980
# state saved, iteration 135990
# state saved, iteration 136000
# state saved, iteration 136010
# state saved, iteration 136020
# state saved, iteration 136030
# state saved, iteration 136040
# state saved, iteration 136050
# state saved, iteration 136060
# state saved, iteration 136070
# state saved, iteration 136080
# state saved, iteration 136090
# state saved, iteration 136100
# state saved, iteration 136110
# state saved, iteration 136120
# state saved, iteration 136130
# state saved, iteration 136140
# state saved, iteration 136150
# state saved, iteration 136160
# state saved, iteration 136170
# state saved, iteration 136180
# state saved, iteration 136190
# state saved, iteration 136200
# state saved, iteration 136210
# state saved, iteration 136220
# state saved, iteration 136230
# state saved, iteration 136240
# state saved, iteration 136250
# state saved, iteration 136260
# state saved, iteration 136270
# state saved, iteration 136280
# state saved, iteration 136290
# state saved, iteration 136300
# state saved, iteration 136310
# state saved, iteration 136320
# state saved, iteration 136330
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-5:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-99e2e5c3aaef> in <module>()
#       1 iteration, urls_to_visit = load_state()
# ----> 2 download_wiki(iteration, urls_to_visit, need_log=False)
#
# <ipython-input-12-bc5149822ef3> in download_wiki(iteration, urls_to_visit, need_log)
#      29                     continue
#      30                 else:
# ---> 31                     completed_result = results[0].get()
#      32                     results.pop(0)
#      33             if completed_result is None:
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
